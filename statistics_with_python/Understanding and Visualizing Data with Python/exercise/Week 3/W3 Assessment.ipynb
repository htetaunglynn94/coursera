# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', None)
# %matplotlib inline
path = 'Cartwheeldata.csv'

# %%
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
# 3   4   39      F            1       N             0    64.0      63.0
# 4   5   27      M            2       N             0    73.0      75.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8
# 2          85        Y              1      7
# 3          87        Y              1     10
# 4          72        N              0      4

# %% [markdown]
# # Scatter plots

# %%
sns.scatterplot(x='Height', y='Wingspan', data=df)
# Out:
# <Axes: xlabel='Height', ylabel='Wingspan'>

# %%
sns.scatterplot(x='Height', y='Wingspan', hue='Gender', data=df)
# Out:
# <Axes: xlabel='Height', ylabel='Wingspan'>

# %%
sns.scatterplot(x='Wingspan', y='CWDistance', data=df)
# Out:
# <Axes: xlabel='Wingspan', ylabel='CWDistance'>

# %%
sns.scatterplot(x='Wingspan', y='CWDistance', hue='Gender', data=df)
# Out:
# <Axes: xlabel='Wingspan', ylabel='CWDistance'>

# %% [markdown]
# # Barcharts

# %%
sns.barplot(x='Glasses', y='CWDistance', data=df)
# Out:
# <Axes: xlabel='Glasses', ylabel='CWDistance'>

# %%
sns.barplot(x='Glasses', y='CWDistance', hue='Gender', data=df)
# Out:
# <Axes: xlabel='Glasses', ylabel='CWDistance'>

# %%
sns.boxplot(x='Glasses', y='CWDistance', hue='Gender', data=df)
# Out:
# <Axes: xlabel='Glasses', ylabel='CWDistance'>

# %%
sns.boxplot(y='Wingspan', data=df)
# Out:
# <Axes: ylabel='Wingspan'>

# %%
sns.boxplot(y='CWDistance', data=df)
# Out:
# <Axes: ylabel='CWDistance'>

# %%
stats.iqr(df['Wingspan']), stats.iqr(df['CWDistance'])
# Out:
# (9.0, 22.0)

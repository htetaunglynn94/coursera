# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # **Hyperparameter Optimization for Keras with Scikit-Learn**

# %% [markdown]
# Estimated time needed: **35** minutes

# %% [markdown]
# We already know how to use `RandomizedSearchCV` and `GridSearchCV` for hyperparameter tuning in machine learning models - linear regression,  decision trees, and so on. It turns out that we can utilize the same functionality easily for neural networks! Keras offers a scikit-learn wrapper that lets us perform randomized/grid search on its models using the same syntax (example `fit()`, `.best_score_`). In this lab, we will take a look at how to do so for a Sequential model.
#
# As a reminder, both search types may take a long time to run for this lab.

# %% [markdown]
# ## **Table of Contents**
#
# <ol>
#     <li><a href="https://#Objectives">Objectives</a></li>
#     <li>
#         <a href="https://#Setup">Setup</a>
#         <ol>
#             <li><a href="https://#Installing-Required-Libraries">Installing Required Libraries</a></li>
#             <li><a href="https://#Importing-Required-Libraries">Importing Required Libraries</a></li>
#             <li><a href="https://#Defining-Helper-Functions">Defining Helper Functions</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="https://#Create-the-Model">Create the Model</a>
#         <ol>
#             <li><a href="https://#Load-the-Data">Load the Data</a></li>
#             <li><a href="https://#Data-Wrangling">Data Wrangling</a></li>
#             <li><a href="https://#Build-the-Base-Model">Build the Base Model</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="https://#Randomized-Search">Randomized Search</a>
#         <ol>
#             <li><a href="https://#Parameters">Parameters</a></li>
#             <li><a href="https://#Define-and-Fit-RandomizedSearchCV">Define and Fit RandomizedSearchCV</a></li>
#             <li><a href="https://#Performance-Evaluation">Performance Evaluation</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="https://#Exercised">Exercises</a>
#         <ol>
#             <li><a href="https://#Exercise-1:-Build-the-Base-Model">Exercise 1: Build the Base Model</a></li>
#             <li><a href="https://#Exercise-2:-Define-Search-Parameters">Exercise 2: Define Search Parameters</a></li>
#             <li><a href="https://#Exercise-3:-Fit-RandomizedSearchCV">Exercise 3: Fit RandomizedSearchCV</a></li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# ## Objectives
#
# After completing this lab you will be able to:
#
# *   Use Keras' scikit-learn wrapper to utilize sklearn functions on Keras models
# *   Apply randomized search on Keras models to find the best hyperparameters

# %% [markdown]
# ***

# %% [markdown]
# ## Setup

# %% [markdown]
# For this lab, we will be using the following libraries:
#
# *   [`numpy`](https://numpy.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for mathematical operations.
# *   [`sklearn`](https://scikit-learn.org/stable/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for machine learning and machine-learning-pipeline related functions.
# *   [`matplotlib`](https://matplotlib.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for additional plotting tools.
# *   [`tensorflow`](https://www.tensorflow.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for machine learning and neural network related functions.

# %% [markdown]
# ### Installing Required Libraries
#
# The following required libraries are pre-installed in the Skills Network Labs environment. However, if you run this notebook command in a different Jupyter environment (like Watson Studio or Anaconda), you will need to install these libraries by removing the `#` sign before `!mamba` in the following code cell.

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented.
# !mamba install -qy numpy==1.21.4 matplotlib==3.5.0 scikit-learn==0.20.1
# Note: If your environment doesn't support "!mamba install", use "!pip install"

# %%
# !pip install -U scikit-learn scikeras tensorflow keras

# %%
# !pip install scikeras
# Out:
# Requirement already satisfied: scikeras in /usr/local/lib/python3.12/dist-packages (0.13.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikeras) (3.12.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from scikeras) (1.7.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (3.15.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.17.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.5.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (25.0)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.6.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from optree->keras>=3.2.0->scikeras) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->scikeras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->scikeras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)

# %% [markdown]
# The following required libraries are **not** pre-installed in the Skills Network Labs environment. **You will need to run the following cell** to install them:

# %%
#!mamba install -qy tqdm

# %%
# Upgrade to newest version of skillsnetwork for more functionalities
# Restart kernel after doing so
# !pip install --upgrade skillsnetwork
# Out:
# Requirement already satisfied: skillsnetwork in /usr/local/lib/python3.12/dist-packages (0.21.10)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from skillsnetwork) (7.34.0)
# Requirement already satisfied: ipywidgets<=8.1.3 in /usr/local/lib/python3.12/dist-packages (from skillsnetwork) (7.7.1)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.12/dist-packages (from skillsnetwork) (2.32.4)
# Requirement already satisfied: tqdm<5,>=4 in /usr/local/lib/python3.12/dist-packages (from skillsnetwork) (4.67.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<=8.1.3->skillsnetwork) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<=8.1.3->skillsnetwork) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<=8.1.3->skillsnetwork) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<=8.1.3->skillsnetwork) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<=8.1.3->skillsnetwork) (3.0.15)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython->skillsnetwork) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython->skillsnetwork) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->skillsnetwork) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->skillsnetwork) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->skillsnetwork) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->skillsnetwork) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->skillsnetwork) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython->skillsnetwork) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->skillsnetwork) (4.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->skillsnetwork) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->skillsnetwork) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->skillsnetwork) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->skillsnetwork) (2025.10.5)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (7.4.9)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (1.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (6.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->skillsnetwork) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->skillsnetwork) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->skillsnetwork) (0.2.14)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (6.5.7)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (5.9.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (2.9.0.post0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (3.1.6)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (25.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.23.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.3.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (4.5.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (4.25.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (1.17.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (25.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.28.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.12/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (2.14.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (2.0.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (4.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (2.23)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (4.11.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.9.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.3.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (24.11.1)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.3.0)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.4.0)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.12/dist-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (2025.2)

# %% [markdown]
# ### Importing Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from tqdm import tqdm
import skillsnetwork

from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout

from scikeras.wrappers import KerasClassifier

# %% [markdown]
# ```python
# import os
# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' # tensorflow INFO and WARNING messages are not printed
# # You can also use this section to suppress warnings generated by your code:
# def warn(*args, **kwargs):
#     pass
# import warnings
# warnings.warn = warn
# warnings.filterwarnings('ignore')
#
# from tqdm import tqdm
# import numpy as np
# %matplotlib inline
#
# import tensorflow as tf
# import keras
# from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Dropout
# from keras.wrappers.scikit_learn import KerasClassifier
#
# import skillsnetwork
# ```

# %% [markdown]
# ### Defining Helper Functions

# %%
# Vectorize integer sequence
def vectorize_sequence(sequence, dimensions): # (input_data, target dim)
    # Create fixed numpy array
    results = np.zeros((len(sequence), dimensions)) # shape: (8982, 30980)

    for index, value in enumerate(sequence):
        # print(f"{value} | {max(value)} & {dimensions}")
        # Make sure "max()" to be lower < max dimensions
        if max(value) < dimensions:
            results[index, value] = 1
        # print(results)
    return results

# Convert label into one-hot format
def one_hot_label(labels, dimensions):
    # Create same shape like input dimensions
    results = np.zeros((len(labels), dimensions))
    for index, value in enumerate(labels):
        if value < dimensions:
            results[index, value] = 1
    return results

# %% [markdown]
# ## Create the Model

# %% [markdown]
# ### Load the Data

# %% [markdown]
# For this exercise, we will be using the [Reuters newswire classification dataset](https://keras.io/api/datasets/reuters/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML311Coursera35714171-2022-01-01) from Keras. The training features for this dataset are lists of word indices (integers), corresponding to their frequency in the dataset. The response labels take on one of 46 classes, representing the newswire's topic.

# %%
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML311-Coursera/labs/Module2/L1/reuters.npz"
await skillsnetwork.prepare(url, overwrite=True)
# Out:
# Downloading reuters.npz:   0%|          | 0/2110848 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# Saved to '.'

# %% [markdown]
# `.npy` file is a binary file format used to save a **single NumPy array** to disk.

# %%
X = np.load("x.npy", allow_pickle=True)
y = np.load("y.npy", allow_pickle=True)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((8982,), (2246,), (8982,), (2246,))

# %% [markdown]
# To get the word for a specific index, we can also extract a dictionary of words to index using the following Keras function.

# %%
word_to_ind = tf.keras.datasets.reuters.get_word_index(path="reuters_word_index.json")
len(word_to_ind)
# Out:
# 30979

# %% [markdown]
# ### Data Wrangling

# %% [markdown]
# Since each observation is a list of words that appear in the newswire, the length varies. Hence, we will vectorize the dataset using `vectorize_sequence()` to ensure that all inputs to our model have the same dimension. Labels are also one-hot encoded with `one_hot_label()` because classes (news topic) are not ordinal.

# %%
dim_x = max([max(s) for s in X_train]) + 1 # to know total number of columns
dim_y = max(y_train) + 1                   # to know total number of columns
print(dim_x, dim_y)
# Out:
# 30980 46

# %% [markdown]
# **Test function using sample data**

# %%
# Small sample data
sample_sequence = [[1, 5, 2], [3, 1], [2, 4, 5, 1]]
sample_dimensions = 7 # Let's assume a vocabulary size of 7

print("Original sample sequences:")
print(sample_sequence)

print("\nVectorized sample sequences:")
print(vectorize_sequence(sample_sequence, sample_dimensions))
# vectorize_sequence(sample_sequence, sample_dimensions)
# Out:
# Original sample sequences:
# [[1, 5, 2], [3, 1], [2, 4, 5, 1]]
#
# Vectorized sample sequences:
# [[0. 1. 1. 0. 0. 1. 0.]
#  [0. 1. 0. 1. 0. 0. 0.]
#  [0. 1. 1. 0. 1. 1. 0.]]

# %%
X_train_vec = vectorize_sequence(X_train, dim_x)
X_test_vec = vectorize_sequence(X_test, dim_x)
X_train_vec.shape, X_test_vec.shape
# We can see here number of columns are fixed.
# Out:
# ((8982, 30980), (2246, 30980))

# %%
y_train_hot = one_hot_label(y_train, dim_y)
y_test_hot  = one_hot_label(y_test, dim_y)
y_train_hot.shape, y_test_hot.shape
# We can see here number of columns are fixed.
# Out:
# ((8982, 46), (2246, 46))

# %% [markdown]
# ### Build the Base Model

# %% [markdown]
# In order to apply `RandomizedSearchCV` on Keras models, we will be using `KerasClassifier` from `keras.wrappers.scikit_learn` library, which will let us apply scikit-learn functions on the model.

# %% [markdown]
# We define `create_model()` below to detail which layers we want to include in the model. Recall that the final Dense layer has 46 units to correspond to the number of classes. This also prompts us to use categorical cross entropy as a loss function. Here, `neuron` is included as a parameter with default value because we want to tune it later.

# %%
# Create Keras Sequential Model as base model
def create_model(neurons = 10):
    model = Sequential()
    model.add(Input(shape=(dim_x, )))
    model.add(Dense(neurons, activation='linear'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(46, activation='softmax'))
    model.compile(optimizer = 'RMSprop',
                  loss = 'categorical_crossentropy',
                  metrics = ['accuracy'])
    return model

# %% [markdown]
# For the base model, we won't change any parameters so that we can compare them with results after hyperparameter tuning. We also specify some of the default values for hyperparameters that don't appear in `create_model()` (example batch_size, epochs) such that they are defined when applying randomized search.

# %%
np.random.seed(0)
base_model = KerasClassifier(model = create_model,
                             verbose = 2,
                             batch_size = 10,
                             epochs = 1)

# %% [markdown]
# Fitting the model on the train set, we obtain the test score for our base model.

# %%
# Get pre-tuned results
base_model.fit(X_train_vec, y_train_hot)
base_score = base_model.score(X_test_vec, y_test_hot)
print("The baseline accuracy is: %.3f" % base_score)
# Out:
# 899/899 - 6s - 7ms/step - accuracy: 0.6512 - loss: 1.5172
# 225/225 - 1s - 2ms/step
# The baseline accuracy is: 0.727

# %% [markdown]
# ## Randomized Search

# %% [markdown]
# ### Parameters

# %% [markdown]
# As you might already know from performing randomized search on machine learning models, we have to create a dictionary for the hyperparameter values. Let's start by defining the values we want to experiment with! Note that if you would like to test other parameters, they must be defined in the base model as well.

# %%
batch_size = [10, 20, 60, 80]
epochs = [1, 3, 5]
neurons = [1, 10, 20, 30]

params = dict(batch_size=batch_size, epochs=epochs, model__neurons=neurons)
print(params)
# Out:
# {'batch_size': [10, 20, 60, 80], 'epochs': [1, 3, 5], 'model__neurons': [1, 10, 20, 30]}

# %% [markdown]
# ### Define and Fit RandomizedSearchCV

# %%
search = RandomizedSearchCV(estimator = base_model,
                            param_distributions = params,
                            cv = 3) # number of folds for cross-validation

# %% [markdown]
# **Cross-validation** is a technique used to evaluate the performance of a machine learning model on a limited dataset.
# - It helps to ensure that the model's performance is not overly dependent on the specific split of the data into training and testing sets.
# - When you set `cv = 3`, the RandomizedSearchCV process will divide the training data (X_train_vec, y_train_hot) into 3 equally sized subsets (folds).
# - It will then train the model 3 times, each time using 2 of the folds for training and the remaining 1 fold for validation.
# - The performance metric (in this case, accuracy, as specified in the compile method of the Keras model) is calculated on the validation fold for each of the 3 training runs.
# - RandomizedSearchCV then averages the performance across these 3 folds to get a more robust estimate of how well the model performs with a given set of hyperparameters.

# %% [markdown]
# Now, fit randomized search on `X_train_vec` and `y_train_hot` as you would for any other model. **Note that this may take a while to run (10+ minutes)**, especially if there are a lot of parameter combinations, or if the epoch size is big. If you have the resources, you could also switch out `RandomizedSearchCV` for `GridSearchCV` to search over every combination of hyperparameters (takes even more time to run).

# %%
search_result = search.fit(X_train_vec, y_train_hot)
# Out:
# Epoch 1/3
# 100/100 - 3s - 26ms/step - accuracy: 0.5453 - loss: 2.2058
# Epoch 2/3
# 100/100 - 1s - 12ms/step - accuracy: 0.6969 - loss: 1.3325
# Epoch 3/3
# 100/100 - 1s - 13ms/step - accuracy: 0.7573 - loss: 1.0388
# 50/50 - 0s - 7ms/step
# Epoch 1/3
# 100/100 - 2s - 23ms/step - accuracy: 0.5406 - loss: 2.1626
# Epoch 2/3
# 100/100 - 2s - 17ms/step - accuracy: 0.7012 - loss: 1.3115
# Epoch 3/3
# 100/100 - 2s - 18ms/step - accuracy: 0.7632 - loss: 1.0257
# 50/50 - 0s - 7ms/step
# Epoch 1/3
# 100/100 - 2s - 20ms/step - accuracy: 0.5423 - loss: 2.2525
# Epoch 2/3
# 100/100 - 1s - 13ms/step - accuracy: 0.6862 - loss: 1.3360
# Epoch 3/3
# 100/100 - 1s - 13ms/step - accuracy: 0.7619 - loss: 1.0296
# 50/50 - 0s - 7ms/step
# Epoch 1/3
# 599/599 - 3s - 5ms/step - accuracy: 0.3564 - loss: 2.2982
# Epoch 2/3
# 599/599 - 2s - 3ms/step - accuracy: 0.4883 - loss: 1.7825
# Epoch 3/3
# 599/599 - 2s - 3ms/step - accuracy: 0.5603 - loss: 1.6537
# 300/300 - 1s - 2ms/step
# Epoch 1/3
# 599/599 - 3s - 6ms/step - accuracy: 0.3644 - loss: 2.2402
# Epoch 2/3
# 599/599 - 2s - 3ms/step - accuracy: 0.4836 - loss: 1.7956
# Epoch 3/3
# 599/599 - 2s - 3ms/step - accuracy: 0.5640 - loss: 1.6825
# 300/300 - 1s - 2ms/step
# Epoch 1/3
# 599/599 - 4s - 6ms/step - accuracy: 0.3524 - loss: 2.2823
# Epoch 2/3
# 599/599 - 2s - 3ms/step - accuracy: 0.4588 - loss: 1.8288
# Epoch 3/3
# 599/599 - 2s - 3ms/step - accuracy: 0.5608 - loss: 1.7027
# 300/300 - 1s - 2ms/step
# 100/100 - 2s - 23ms/step - accuracy: 0.6075 - loss: 1.9402
# 50/50 - 1s - 12ms/step
# 100/100 - 2s - 23ms/step - accuracy: 0.6014 - loss: 1.9734
# 50/50 - 0s - 8ms/step
# 100/100 - 2s - 23ms/step - accuracy: 0.5785 - loss: 2.0928
# 50/50 - 1s - 12ms/step
# Epoch 1/3
# 100/100 - 2s - 23ms/step - accuracy: 0.5691 - loss: 1.9764
# Epoch 2/3
# 100/100 - 1s - 15ms/step - accuracy: 0.7497 - loss: 1.1270
# Epoch 3/3
# 100/100 - 2s - 15ms/step - accuracy: 0.8257 - loss: 0.8056
# 50/50 - 0s - 7ms/step
# Epoch 1/3
# 100/100 - 3s - 28ms/step - accuracy: 0.5912 - loss: 1.8923
# Epoch 2/3
# 100/100 - 2s - 24ms/step - accuracy: 0.7463 - loss: 1.1096
# Epoch 3/3
# 100/100 - 1s - 15ms/step - accuracy: 0.8195 - loss: 0.7978
# 50/50 - 0s - 7ms/step
# Epoch 1/3
# 100/100 - 3s - 32ms/step - accuracy: 0.5691 - loss: 1.9414
# Epoch 2/3
# 100/100 - 2s - 15ms/step - accuracy: 0.7371 - loss: 1.1463
# Epoch 3/3
# 100/100 - 2s - 25ms/step - accuracy: 0.8116 - loss: 0.8288
# 50/50 - 0s - 7ms/step
# Epoch 1/5
# 100/100 - 1s - 15ms/step - accuracy: 0.2849 - loss: 2.9991
# Epoch 2/5
# 100/100 - 1s - 7ms/step - accuracy: 0.3525 - loss: 2.2045
# Epoch 3/5
# 100/100 - 1s - 9ms/step - accuracy: 0.3567 - loss: 2.0121
# Epoch 4/5
# 100/100 - 1s - 14ms/step - accuracy: 0.3651 - loss: 1.8938
# Epoch 5/5
# 100/100 - 1s - 9ms/step - accuracy: 0.3925 - loss: 1.7814
# 50/50 - 0s - 6ms/step
# Epoch 1/5
# 100/100 - 2s - 15ms/step - accuracy: 0.4626 - loss: 3.0680
# Epoch 2/5
# 100/100 - 1s - 13ms/step - accuracy: 0.4868 - loss: 2.0268
# Epoch 3/5
# 100/100 - 1s - 7ms/step - accuracy: 0.4965 - loss: 1.8451
# Epoch 4/5
# 100/100 - 1s - 7ms/step - accuracy: 0.5082 - loss: 1.7673
# Epoch 5/5
# 100/100 - 1s - 7ms/step - accuracy: 0.5224 - loss: 1.6986
# 50/50 - 0s - 9ms/step
# Epoch 1/5
# 100/100 - 1s - 15ms/step - accuracy: 0.2944 - loss: 2.9452
# Epoch 2/5
# 100/100 - 1s - 7ms/step - accuracy: 0.3530 - loss: 2.1913
# Epoch 3/5
# 100/100 - 1s - 12ms/step - accuracy: 0.3550 - loss: 2.0134
# Epoch 4/5
# 100/100 - 1s - 7ms/step - accuracy: 0.3591 - loss: 1.9052
# Epoch 5/5
# 100/100 - 1s - 12ms/step - accuracy: 0.3804 - loss: 1.8067
# 50/50 - 0s - 6ms/step
# 75/75 - 3s - 34ms/step - accuracy: 0.5205 - loss: 2.3271
# 38/38 - 0s - 9ms/step
# 75/75 - 2s - 25ms/step - accuracy: 0.5282 - loss: 2.3769
# 38/38 - 0s - 9ms/step
# 75/75 - 3s - 34ms/step - accuracy: 0.5316 - loss: 2.3167
# 38/38 - 0s - 11ms/step
# Epoch 1/5
# 100/100 - 2s - 23ms/step - accuracy: 0.5878 - loss: 1.9620
# Epoch 2/5
# 100/100 - 2s - 15ms/step - accuracy: 0.7523 - loss: 1.0890
# Epoch 3/5
# 100/100 - 2s - 17ms/step - accuracy: 0.8226 - loss: 0.7846
# Epoch 4/5
# 100/100 - 2s - 22ms/step - accuracy: 0.8699 - loss: 0.5719
# Epoch 5/5
# 100/100 - 2s - 18ms/step - accuracy: 0.9061 - loss: 0.4218
# 50/50 - 0s - 8ms/step
# Epoch 1/5
# 100/100 - 2s - 22ms/step - accuracy: 0.6027 - loss: 1.9247
# Epoch 2/5
# 100/100 - 2s - 15ms/step - accuracy: 0.7482 - loss: 1.1096
# Epoch 3/5
# 100/100 - 2s - 20ms/step - accuracy: 0.8243 - loss: 0.7964
# Epoch 4/5
# 100/100 - 2s - 19ms/step - accuracy: 0.8704 - loss: 0.5739
# Epoch 5/5
# 100/100 - 2s - 21ms/step - accuracy: 0.9132 - loss: 0.4148
# 50/50 - 0s - 8ms/step
# Epoch 1/5
# 100/100 - 2s - 23ms/step - accuracy: 0.5865 - loss: 2.0776
# Epoch 2/5
# 100/100 - 3s - 30ms/step - accuracy: 0.7260 - loss: 1.1830
# Epoch 3/5
# 100/100 - 1s - 15ms/step - accuracy: 0.8064 - loss: 0.8589
# Epoch 4/5
# 100/100 - 1s - 15ms/step - accuracy: 0.8594 - loss: 0.6171
# Epoch 5/5
# 100/100 - 2s - 15ms/step - accuracy: 0.9053 - loss: 0.4435
# 50/50 - 0s - 8ms/step
# Epoch 1/3
# 75/75 - 2s - 20ms/step - accuracy: 0.3504 - loss: 3.0171
# Epoch 2/3
# 75/75 - 2s - 21ms/step - accuracy: 0.3525 - loss: 2.2365
# Epoch 3/3
# 75/75 - 1s - 12ms/step - accuracy: 0.3559 - loss: 2.0333
# 38/38 - 0s - 8ms/step
# Epoch 1/3
# 75/75 - 1s - 19ms/step - accuracy: 0.4549 - loss: 3.2540
# Epoch 2/3
# 75/75 - 1s - 9ms/step - accuracy: 0.4875 - loss: 2.1808
# Epoch 3/3
# 75/75 - 1s - 8ms/step - accuracy: 0.5050 - loss: 1.8736
# 38/38 - 0s - 7ms/step
# Epoch 1/3
# 75/75 - 2s - 25ms/step - accuracy: 0.3398 - loss: 3.2059
# Epoch 2/3
# 75/75 - 1s - 13ms/step - accuracy: 0.3529 - loss: 2.3276
# Epoch 3/3
# 75/75 - 1s - 10ms/step - accuracy: 0.3545 - loss: 2.0752
# 38/38 - 0s - 8ms/step
# Epoch 1/3
# 599/599 - 7s - 12ms/step - accuracy: 0.6759 - loss: 1.4591
# Epoch 2/3
# 599/599 - 10s - 17ms/step - accuracy: 0.8151 - loss: 0.8072
# Epoch 3/3
# 599/599 - 7s - 11ms/step - accuracy: 0.8851 - loss: 0.5284
# 300/300 - 1s - 3ms/step
# Epoch 1/3
# 599/599 - 7s - 12ms/step - accuracy: 0.6747 - loss: 1.4443
# Epoch 2/3
# 599/599 - 7s - 11ms/step - accuracy: 0.8210 - loss: 0.8196
# Epoch 3/3
# 599/599 - 6s - 10ms/step - accuracy: 0.8826 - loss: 0.5378
# 300/300 - 1s - 3ms/step
# Epoch 1/3
# 599/599 - 7s - 13ms/step - accuracy: 0.6635 - loss: 1.4970
# Epoch 2/3
# 599/599 - 6s - 11ms/step - accuracy: 0.8171 - loss: 0.8330
# Epoch 3/3
# 599/599 - 10s - 16ms/step - accuracy: 0.8856 - loss: 0.5398
# 300/300 - 1s - 4ms/step
# Epoch 1/5
# 599/599 - 5s - 9ms/step - accuracy: 0.6602 - loss: 1.5258
# Epoch 2/5
# 599/599 - 5s - 9ms/step - accuracy: 0.8076 - loss: 0.8646
# Epoch 3/5
# 599/599 - 5s - 8ms/step - accuracy: 0.8677 - loss: 0.5992
# Epoch 4/5
# 599/599 - 5s - 8ms/step - accuracy: 0.9018 - loss: 0.4441
# Epoch 5/5
# 599/599 - 6s - 9ms/step - accuracy: 0.9205 - loss: 0.3477
# 300/300 - 1s - 2ms/step
# Epoch 1/5
# 599/599 - 6s - 10ms/step - accuracy: 0.6643 - loss: 1.5165
# Epoch 2/5
# 599/599 - 5s - 8ms/step - accuracy: 0.8069 - loss: 0.8862
# Epoch 3/5
# 599/599 - 5s - 8ms/step - accuracy: 0.8599 - loss: 0.6206
# Epoch 4/5
# 599/599 - 6s - 9ms/step - accuracy: 0.9005 - loss: 0.4581
# Epoch 5/5
# 599/599 - 11s - 19ms/step - accuracy: 0.9259 - loss: 0.3550
# 300/300 - 1s - 3ms/step
# Epoch 1/5
# 599/599 - 7s - 11ms/step - accuracy: 0.6508 - loss: 1.5474
# Epoch 2/5
# 599/599 - 10s - 16ms/step - accuracy: 0.7989 - loss: 0.9027
# Epoch 3/5
# 599/599 - 5s - 9ms/step - accuracy: 0.8641 - loss: 0.6184
# Epoch 4/5
# 599/599 - 5s - 8ms/step - accuracy: 0.9015 - loss: 0.4567
# Epoch 5/5
# 599/599 - 6s - 9ms/step - accuracy: 0.9232 - loss: 0.3451
# 300/300 - 1s - 2ms/step
# Epoch 1/3
# 899/899 - 12s - 13ms/step - accuracy: 0.7010 - loss: 1.3658
# Epoch 2/3
# 899/899 - 10s - 11ms/step - accuracy: 0.8346 - loss: 0.7520
# Epoch 3/3
# 899/899 - 10s - 11ms/step - accuracy: 0.8864 - loss: 0.5175

# %% [markdown]
# ### Performance Evaluation

# %% [markdown]
# Let's take a look at the results from this search! In particular, we will examine the mean and standard deviation of the cross-validation score under different hyperparameter combinations.

# %%
# All available keys
items = search_result.cv_results_.items()

# %%
for key, val in items:
    print(f"key: {key} \nvalue: {val}")
    print("-"*50)
# Out:
# key: mean_fit_time
# value: [ 7.76965308  9.62239464  4.48651703  9.35826302  7.83486454  5.47756886
#  12.22361708  5.58555818 25.88770572 32.78964289]
# --------------------------------------------------
# key: std_fit_time
# value: [0.71095071 0.09111607 0.07086884 0.56866811 0.54238239 1.04616275
#  0.52493826 0.49441812 2.83004067 3.45118058]
# --------------------------------------------------
# key: mean_score_time
# value: [1.11952432 1.40908583 1.34474007 1.1934855  1.14864866 1.11684108
#  1.20373599 1.03370047 1.93169641 1.7905728 ]
# --------------------------------------------------
# key: std_score_time
# value: [0.01662501 0.01969366 0.15104066 0.11562351 0.16503928 0.02811338
#  0.08197122 0.03348837 0.22731812 0.32259865]
# --------------------------------------------------
# key: param_model__neurons
# value: [10 1 20 20 1 10 20 1 30 20]
# --------------------------------------------------
# key: param_epochs
# value: [3 3 1 3 5 1 5 3 3 5]
# --------------------------------------------------
# key: param_batch_size
# value: [60 10 60 60 60 80 60 80 10 10]
# --------------------------------------------------
# key: params
# value: [{'model__neurons': 10, 'epochs': 3, 'batch_size': 60}, {'model__neurons': 1, 'epochs': 3, 'batch_size': 10}, {'model__neurons': 20, 'epochs': 1, 'batch_size': 60}, {'model__neurons': 20, 'epochs': 3, 'batch_size': 60}, {'model__neurons': 1, 'epochs': 5, 'batch_size': 60}, {'model__neurons': 10, 'epochs': 1, 'batch_size': 80}, {'model__neurons': 20, 'epochs': 5, 'batch_size': 60}, {'model__neurons': 1, 'epochs': 3, 'batch_size': 80}, {'model__neurons': 30, 'epochs': 3, 'batch_size': 10}, {'model__neurons': 20, 'epochs': 5, 'batch_size': 10}]
# --------------------------------------------------
# key: split0_test_score
# value: [0.7247829  0.56646627 0.67802271 0.76085504 0.4488978  0.62057448
#  0.78657315 0.36873747 0.79191717 0.78557114]
# --------------------------------------------------
# key: split1_test_score
# value: [0.73046092 0.54108216 0.67768871 0.75885104 0.51436206 0.5988644
#  0.78156313 0.49866399 0.79024716 0.78490314]
# --------------------------------------------------
# key: split2_test_score
# value: [0.74248497 0.55878424 0.69539078 0.77321309 0.43086172 0.63894456
#  0.79392118 0.36305945 0.7999332  0.78957916]
# --------------------------------------------------
# key: mean_test_score
# value: [0.73257626 0.55544422 0.68370073 0.76430639 0.46470719 0.61946114
#  0.78735248 0.41015364 0.79403251 0.78668448]
# --------------------------------------------------
# key: std_test_score
# value: [0.00738001 0.01062873 0.00826724 0.00635091 0.03587505 0.01638158
#  0.00507516 0.06262918 0.00422775 0.00206493]
# --------------------------------------------------
# key: rank_test_score
# value: [ 5  8  6  4  9  7  2 10  1  3]
# --------------------------------------------------

# %%
means = search_result.cv_results_['mean_test_score']
stds = search_result.cv_results_['std_test_score']
params = search_result.cv_results_['params']

# %% [markdown]
# `RandomizedSearchCV` also has attributes for us to access the best score and parameters directly.

# %%
print("Best mean cross-validated score: {} using {}" \
      .format(search_result.best_score_, search_result.best_params_))
# Out:
# Best mean cross-validated score: 0.7940325094633712 using {'model__neurons': 30, 'epochs': 3, 'batch_size': 10}

# %% [markdown]
# We can also print out all the other scores:

# %%
for mean, stdev, param in zip(means, stds, params):
    print("Mean cross-validated score: {} ({}) using: {}" \
          .format(round(mean,3), round(stdev,3), param))
# Out:
# Mean cross-validated score: 0.733 (0.007) using: {'model__neurons': 10, 'epochs': 3, 'batch_size': 60}
# Mean cross-validated score: 0.555 (0.011) using: {'model__neurons': 1, 'epochs': 3, 'batch_size': 10}
# Mean cross-validated score: 0.684 (0.008) using: {'model__neurons': 20, 'epochs': 1, 'batch_size': 60}
# Mean cross-validated score: 0.764 (0.006) using: {'model__neurons': 20, 'epochs': 3, 'batch_size': 60}
# Mean cross-validated score: 0.465 (0.036) using: {'model__neurons': 1, 'epochs': 5, 'batch_size': 60}
# Mean cross-validated score: 0.619 (0.016) using: {'model__neurons': 10, 'epochs': 1, 'batch_size': 80}
# Mean cross-validated score: 0.787 (0.005) using: {'model__neurons': 20, 'epochs': 5, 'batch_size': 60}
# Mean cross-validated score: 0.41 (0.063) using: {'model__neurons': 1, 'epochs': 3, 'batch_size': 80}
# Mean cross-validated score: 0.794 (0.004) using: {'model__neurons': 30, 'epochs': 3, 'batch_size': 10}
# Mean cross-validated score: 0.787 (0.002) using: {'model__neurons': 20, 'epochs': 5, 'batch_size': 10}

# %% [markdown]
# From this, we can see how different the other models' scores are compared to the optimal model's performance. Some are pretty close to the best score, whereas there are combinations that yield much lower scores. Thank goodness we didn't pick those! With randomized search on neural networks, we are able to determine the best values in an automated way.

# %% [markdown]
# Using the best estimator, let's get the test score:

# %%
search_result.best_estimator_.score(X_test_vec, y_test_hot)
# Out:
# 225/225 - 1s - 3ms/step
# 0.8040961709706145

# %% [markdown]
# Our test score has increased compared to the base model!

# %% [markdown]
# ## Exercises

# %% [markdown]
# Now, let's try Randomized search on other hyperparameters!

# %% [markdown]
# ### Exercise 1: Build the Base Model

# %% [markdown]
# This time, we want to look at different optimizers, learning rates, and dropout rates. Since the learning rate is a value fed into `optimizer`, the parameter has to be named a certain way in `create_model()` and `params`: `optimizer__learning_rate`.

# %%
# Create Keras Sequential Model as base model
def create_model(optimizer='RMSprop', learning_rate=0.1, dropout_rate=0.2, neurons=64): # Added neurons parameter with default value
    model = Sequential()
    model.add(Input(shape=(dim_x,)))
    model.add(Dense(neurons, activation='linear')) # Use the neurons parameter here
    model.add(Dropout(dropout_rate))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(46, activation='softmax'))
    model.compile(optimizer = optimizer,
                  # learning_rate = learning_rate, # Removed learning_rate from compile
                  loss = 'categorical_crossentropy',
                  metrics = ['accuracy'])
    return model

# %%
np.random.seed(0)

# for e in range(1, 6): # Removed loop for demonstration purposes
base_model = KerasClassifier(model = create_model,
                             verbose = 0,
                             batch_size = 100,
                             epochs = 1, # Set epochs to 5 for baseline
                             optimizer = 'RMSprop', # Set default optimizer
                             learning_rate = 0.01, # Set default learning rate
                             dropout_rate = 0.2) # Explicitly include dropout_rate in constructor
base_model.fit(X_train_vec, y_train_hot)
base_score = base_model.score(X_test_vec, y_test_hot)
print("The baseline accuracy is: {}.".format(base_score))
# Out:
# The baseline accuracy is: 0.748886910062333.

# %% [markdown]
# <details>
#     <summary>Click here for sample solution</summary>
#
# ```python
#
# np.random.seed(0)
# base_model = KerasClassifier(build_fn=create_model, verbose=0, batch_size=100, epochs=1)
# base_model.fit(X_train_vec, y_train_hot)
# base_score = base_model.score(X_test_vec, y_test_hot)
# print("The baseline accuracy is: {}".format(base_score))
#
# ```
#
# </details>

# %% [markdown]
# ### Exercise 2: Define Search Parameters

# %% [markdown]
# Now, we will specify which values we want to experiment with and put them into a dictionary.

# %%
learning_rates = [1, 0.1, 0.001, 0.0001]
optimizers = ['SGD', 'RMSprop', 'Adam']
dropout_rates = [0.1, 0.3, 0.6, 0.9]


params = dict(optimizer__learning_rate = learning_rates,
              optimizer = optimizers,
              dropout_rate = dropout_rates) # Include dropout_rate in params again
params
# Out:
# {'optimizer__learning_rate': [1, 0.1, 0.001, 0.0001],
#  'optimizer': ['SGD', 'RMSprop', 'Adam'],
#  'dropout_rate': [0.1, 0.3, 0.6, 0.9]}

# %% [markdown]
# <details>
#     <summary>Click here for sample solution</summary>
#
# ```python
#
# optimizer = ['SGD','RMSprop','Adam']
# learning_rate = [0.01, 0.1, 1]
# dropout_rate = [0.1, 0.3, 0.6, 0.9]
# params = dict(optimizer=optimizer, optimizer__learning_rate=learning_rate, dropout_rate = dropout_rate)
#
# ```
#
# </details>

# %% [markdown]
# ### Exercise 3: Fit RandomizedSearchCV **(Note that this may take a while to run (5+ minutes))**

# %%
np.random.seed(0)

base_model = KerasClassifier(model = create_model,
                             verbose = 2,
                             batch_size = 100,
                             epochs = 5,
                             optimizer = 'RMSprop',
                             learning_rate = 0.01,
                             dropout_rate = 0.2)

# No need to fit the base_model here, as RandomizedSearchCV will do the fitting
# base_model.fit(X_train_vec, y_train_hot)
# base_score = base_model.score(X_test_vec, y_test_hot)
# print("The baseline accuracy is: {}.".format(base_score))

# %%
search = RandomizedSearchCV(estimator = base_model,
                            param_distributions = params,
                            cv = 3)

search_result = search.fit(X_train_vec, y_train_hot)
# Out:
# Epoch 1/5
# 60/60 - 3s - 54ms/step - accuracy: 0.5402 - loss: 2.1155
# Epoch 2/5
# 60/60 - 3s - 42ms/step - accuracy: 0.6987 - loss: 1.3014
# Epoch 3/5
# 60/60 - 3s - 46ms/step - accuracy: 0.7604 - loss: 1.0429
# Epoch 4/5
# 60/60 - 3s - 58ms/step - accuracy: 0.8019 - loss: 0.8648
# Epoch 5/5
# 60/60 - 2s - 37ms/step - accuracy: 0.8310 - loss: 0.7215
# 30/30 - 1s - 18ms/step
# Epoch 1/5
# 60/60 - 3s - 57ms/step - accuracy: 0.5471 - loss: 2.0856
# Epoch 2/5
# 60/60 - 3s - 56ms/step - accuracy: 0.7051 - loss: 1.2965
# Epoch 3/5
# 60/60 - 4s - 66ms/step - accuracy: 0.7582 - loss: 1.0420
# Epoch 4/5
# 60/60 - 3s - 47ms/step - accuracy: 0.8028 - loss: 0.8676
# Epoch 5/5
# 60/60 - 2s - 38ms/step - accuracy: 0.8385 - loss: 0.7139
# 30/30 - 1s - 33ms/step
# Epoch 1/5
# 60/60 - 3s - 51ms/step - accuracy: 0.5456 - loss: 2.0993
# Epoch 2/5
# 60/60 - 3s - 42ms/step - accuracy: 0.6941 - loss: 1.3249
# Epoch 3/5
# 60/60 - 3s - 43ms/step - accuracy: 0.7652 - loss: 1.0516
# Epoch 4/5
# 60/60 - 3s - 52ms/step - accuracy: 0.8021 - loss: 0.8701
# Epoch 5/5
# 60/60 - 4s - 70ms/step - accuracy: 0.8248 - loss: 0.7282
# 30/30 - 1s - 19ms/step
# Epoch 1/5
# 60/60 - 4s - 69ms/step - accuracy: 0.6209 - loss: 1.8323
# Epoch 2/5
# 60/60 - 2s - 37ms/step - accuracy: 0.7836 - loss: 0.9642
# Epoch 3/5
# 60/60 - 2s - 39ms/step - accuracy: 0.8637 - loss: 0.6345
# Epoch 4/5
# 60/60 - 2s - 38ms/step - accuracy: 0.9093 - loss: 0.4359
# Epoch 5/5
# 60/60 - 2s - 41ms/step - accuracy: 0.9332 - loss: 0.3093
# 30/30 - 1s - 33ms/step
# Epoch 1/5
# 60/60 - 3s - 53ms/step - accuracy: 0.6256 - loss: 1.8003
# Epoch 2/5
# 60/60 - 2s - 37ms/step - accuracy: 0.7817 - loss: 0.9722
# Epoch 3/5
# 60/60 - 3s - 45ms/step - accuracy: 0.8607 - loss: 0.6468
# Epoch 4/5
# 60/60 - 3s - 52ms/step - accuracy: 0.9071 - loss: 0.4313
# Epoch 5/5
# 60/60 - 4s - 71ms/step - accuracy: 0.9340 - loss: 0.3108
# 30/30 - 1s - 17ms/step
# Epoch 1/5
# 60/60 - 4s - 72ms/step - accuracy: 0.6269 - loss: 1.8037
# Epoch 2/5
# 60/60 - 2s - 38ms/step - accuracy: 0.7834 - loss: 0.9733
# Epoch 3/5
# 60/60 - 3s - 44ms/step - accuracy: 0.8555 - loss: 0.6468
# Epoch 4/5
# 60/60 - 2s - 36ms/step - accuracy: 0.9093 - loss: 0.4289
# Epoch 5/5
# 60/60 - 3s - 45ms/step - accuracy: 0.9392 - loss: 0.2991
# 30/30 - 1s - 33ms/step
# Epoch 1/5
# 60/60 - 3s - 53ms/step - accuracy: 0.5364 - loss: 2.0877
# Epoch 2/5
# 60/60 - 2s - 37ms/step - accuracy: 0.7091 - loss: 1.2954
# Epoch 3/5
# 60/60 - 3s - 46ms/step - accuracy: 0.7655 - loss: 1.0170
# Epoch 4/5
# 60/60 - 3s - 49ms/step - accuracy: 0.8091 - loss: 0.8420
# Epoch 5/5
# 60/60 - 2s - 36ms/step - accuracy: 0.8419 - loss: 0.6971
# 30/30 - 1s - 17ms/step
# Epoch 1/5
# 60/60 - 3s - 58ms/step - accuracy: 0.5571 - loss: 2.0376
# Epoch 2/5
# 60/60 - 3s - 49ms/step - accuracy: 0.7052 - loss: 1.2833
# Epoch 3/5
# 60/60 - 2s - 36ms/step - accuracy: 0.7662 - loss: 1.0253
# Epoch 4/5
# 60/60 - 3s - 45ms/step - accuracy: 0.8150 - loss: 0.8491
# Epoch 5/5
# 60/60 - 2s - 36ms/step - accuracy: 0.8385 - loss: 0.7149
# 30/30 - 1s - 18ms/step
# Epoch 1/5
# 60/60 - 3s - 55ms/step - accuracy: 0.5466 - loss: 2.0541
# Epoch 2/5
# 60/60 - 2s - 37ms/step - accuracy: 0.6947 - loss: 1.3256
# Epoch 3/5
# 60/60 - 2s - 38ms/step - accuracy: 0.7550 - loss: 1.0585
# Epoch 4/5
# 60/60 - 2s - 37ms/step - accuracy: 0.7999 - loss: 0.8733
# Epoch 5/5
# 60/60 - 4s - 60ms/step - accuracy: 0.8293 - loss: 0.7429
# 30/30 - 1s - 18ms/step
# Epoch 1/5
# 60/60 - 3s - 53ms/step - accuracy: 0.5585 - loss: 2.0738
# Epoch 2/5
# 60/60 - 2s - 38ms/step - accuracy: 0.7101 - loss: 1.2854
# Epoch 3/5
# 60/60 - 3s - 55ms/step - accuracy: 0.7654 - loss: 1.0229
# Epoch 4/5
# 60/60 - 2s - 37ms/step - accuracy: 0.8091 - loss: 0.8387
# Epoch 5/5
# 60/60 - 2s - 37ms/step - accuracy: 0.8400 - loss: 0.7061
# 30/30 - 1s - 18ms/step
# Epoch 1/5
# 60/60 - 4s - 69ms/step - accuracy: 0.5488 - loss: 2.0273
# Epoch 2/5
# 60/60 - 2s - 38ms/step - accuracy: 0.7031 - loss: 1.2836
# Epoch 3/5
# 60/60 - 2s - 37ms/step - accuracy: 0.7704 - loss: 1.0251
# Epoch 4/5
# 60/60 - 3s - 43ms/step - accuracy: 0.8111 - loss: 0.8521
# Epoch 5/5
# 60/60 - 3s - 42ms/step - accuracy: 0.8390 - loss: 0.7187
# 30/30 - 1s - 35ms/step
# Epoch 1/5
# 60/60 - 3s - 52ms/step - accuracy: 0.5620 - loss: 2.0872
# Epoch 2/5
# 60/60 - 2s - 38ms/step - accuracy: 0.6996 - loss: 1.3108
# Epoch 3/5
# 60/60 - 2s - 37ms/step - accuracy: 0.7602 - loss: 1.0536
# Epoch 4/5
# 60/60 - 3s - 51ms/step - accuracy: 0.8018 - loss: 0.8710
# Epoch 5/5
# 60/60 - 2s - 39ms/step - accuracy: 0.8303 - loss: 0.7394
# 30/30 - 1s - 18ms/step
# Epoch 1/5
# 60/60 - 3s - 53ms/step - accuracy: 0.5474 - loss: 2.0363
# Epoch 2/5
# 60/60 - 3s - 56ms/step - accuracy: 0.7027 - loss: 1.2923
# Epoch 3/5
# 60/60 - 4s - 71ms/step - accuracy: 0.7682 - loss: 1.0117
# Epoch 4/5
# 60/60 - 2s - 42ms/step - accuracy: 0.8081 - loss: 0.8305
# Epoch 5/5
# 60/60 - 3s - 44ms/step - accuracy: 0.8413 - loss: 0.6977
# 30/30 - 1s - 33ms/step
# Epoch 1/5
# 60/60 - 3s - 54ms/step - accuracy: 0.5382 - loss: 2.0891
# Epoch 2/5
# 60/60 - 2s - 37ms/step - accuracy: 0.7051 - loss: 1.2889
# Epoch 3/5
# 60/60 - 2s - 39ms/step - accuracy: 0.7659 - loss: 1.0127
# Epoch 4/5
# 60/60 - 4s - 59ms/step - accuracy: 0.8061 - loss: 0.8455
# Epoch 5/5
# 60/60 - 2s - 37ms/step - accuracy: 0.8358 - loss: 0.7170
# 30/30 - 1s - 19ms/step
# Epoch 1/5
# 60/60 - 4s - 68ms/step - accuracy: 0.5595 - loss: 2.0210
# Epoch 2/5
# 60/60 - 3s - 58ms/step - accuracy: 0.6934 - loss: 1.3017
# Epoch 3/5
# 60/60 - 2s - 38ms/step - accuracy: 0.7619 - loss: 1.0471
# Epoch 4/5
# 60/60 - 2s - 39ms/step - accuracy: 0.8051 - loss: 0.8604
# Epoch 5/5
# 60/60 - 2s - 41ms/step - accuracy: 0.8348 - loss: 0.7249
# 30/30 - 1s - 19ms/step
# Epoch 1/5
# 60/60 - 3s - 56ms/step - accuracy: 0.4345 - loss: 2.4239
# Epoch 2/5
# 60/60 - 2s - 39ms/step - accuracy: 0.5476 - loss: 1.8205
# Epoch 3/5
# 60/60 - 2s - 37ms/step - accuracy: 0.5908 - loss: 1.6584
# Epoch 4/5
# 60/60 - 2s - 38ms/step - accuracy: 0.6197 - loss: 1.5675
# Epoch 5/5
# 60/60 - 3s - 54ms/step - accuracy: 0.6393 - loss: 1.5039
# 30/30 - 1s - 19ms/step
# Epoch 1/5
# 60/60 - 3s - 52ms/step - accuracy: 0.4444 - loss: 2.4631
# Epoch 2/5
# 60/60 - 2s - 37ms/step - accuracy: 0.5513 - loss: 1.8438
# Epoch 3/5
# 60/60 - 3s - 55ms/step - accuracy: 0.5913 - loss: 1.6647
# Epoch 4/5
# 60/60 - 2s - 39ms/step - accuracy: 0.6204 - loss: 1.5616
# Epoch 5/5
# 60/60 - 2s - 41ms/step - accuracy: 0.6373 - loss: 1.4821
# 30/30 - 1s - 18ms/step
# Epoch 1/5
# 60/60 - 4s - 73ms/step - accuracy: 0.4098 - loss: 2.4940
# Epoch 2/5
# 60/60 - 2s - 39ms/step - accuracy: 0.5214 - loss: 1.8675
# Epoch 3/5
# 60/60 - 2s - 38ms/step - accuracy: 0.5813 - loss: 1.6930
# Epoch 4/5
# 60/60 - 3s - 42ms/step - accuracy: 0.6144 - loss: 1.5991
# Epoch 5/5
# 60/60 - 2s - 37ms/step - accuracy: 0.6386 - loss: 1.5222
# 30/30 - 1s - 37ms/step
# Epoch 1/5
# 60/60 - 3s - 56ms/step - accuracy: 0.5631 - loss: 2.0995
# Epoch 2/5
# 60/60 - 2s - 38ms/step - accuracy: 0.7108 - loss: 1.2805
# Epoch 3/5
# 60/60 - 2s - 37ms/step - accuracy: 0.7697 - loss: 1.0204
# Epoch 4/5
# 60/60 - 3s - 55ms/step - accuracy: 0.8108 - loss: 0.8405
# Epoch 5/5
# 60/60 - 2s - 39ms/step - accuracy: 0.8419 - loss: 0.6972
# 30/30 - 1s - 20ms/step
# Epoch 1/5
# 60/60 - 3s - 54ms/step - accuracy: 0.5327 - loss: 2.0952
# Epoch 2/5
# 60/60 - 4s - 59ms/step - accuracy: 0.6979 - loss: 1.3191
# Epoch 3/5
# 60/60 - 2s - 38ms/step - accuracy: 0.7632 - loss: 1.0419
# Epoch 4/5
# 60/60 - 2s - 41ms/step - accuracy: 0.8115 - loss: 0.8542
# Epoch 5/5
# 60/60 - 2s - 37ms/step - accuracy: 0.8398 - loss: 0.7235
# 30/30 - 1s - 17ms/step
# Epoch 1/5
# 60/60 - 3s - 56ms/step - accuracy: 0.5396 - loss: 2.1056
# Epoch 2/5
# 60/60 - 2s - 41ms/step - accuracy: 0.6971 - loss: 1.3187
# Epoch 3/5
# 60/60 - 2s - 39ms/step - accuracy: 0.7605 - loss: 1.0465
# Epoch 4/5
# 60/60 - 2s - 41ms/step - accuracy: 0.8018 - loss: 0.8523
# Epoch 5/5
# 60/60 - 3s - 55ms/step - accuracy: 0.8363 - loss: 0.7142
# 30/30 - 1s - 19ms/step
# Epoch 1/5
# 60/60 - 4s - 59ms/step - accuracy: 0.4046 - loss: 2.5448
# Epoch 2/5
# 60/60 - 3s - 53ms/step - accuracy: 0.5392 - loss: 1.8362
# Epoch 3/5
# 60/60 - 2s - 38ms/step - accuracy: 0.5950 - loss: 1.6527
# Epoch 4/5
# 60/60 - 2s - 39ms/step - accuracy: 0.6237 - loss: 1.5617
# Epoch 5/5
# 60/60 - 2s - 39ms/step - accuracy: 0.6414 - loss: 1.4868
# 30/30 - 1s - 18ms/step
# Epoch 1/5
# 60/60 - 3s - 58ms/step - accuracy: 0.4289 - loss: 2.5515
# Epoch 2/5
# 60/60 - 2s - 39ms/step - accuracy: 0.5436 - loss: 1.8327
# Epoch 3/5
# 60/60 - 2s - 41ms/step - accuracy: 0.5905 - loss: 1.6726
# Epoch 4/5
# 60/60 - 2s - 38ms/step - accuracy: 0.6174 - loss: 1.5794
# Epoch 5/5
# 60/60 - 3s - 53ms/step - accuracy: 0.6423 - loss: 1.4893
# 30/30 - 1s - 18ms/step
# Epoch 1/5
# 60/60 - 3s - 53ms/step - accuracy: 0.4090 - loss: 2.5498
# Epoch 2/5
# 60/60 - 4s - 60ms/step - accuracy: 0.5237 - loss: 1.8929
# Epoch 3/5
# 60/60 - 4s - 66ms/step - accuracy: 0.5750 - loss: 1.7029
# Epoch 4/5
# 60/60 - 2s - 39ms/step - accuracy: 0.6002 - loss: 1.6167
# Epoch 5/5
# 60/60 - 2s - 41ms/step - accuracy: 0.6294 - loss: 1.5390
# 30/30 - 1s - 33ms/step
# Epoch 1/5
# 60/60 - 3s - 52ms/step - accuracy: 0.6029 - loss: 1.8736
# Epoch 2/5
# 60/60 - 2s - 41ms/step - accuracy: 0.7799 - loss: 0.9882
# Epoch 3/5
# 60/60 - 2s - 38ms/step - accuracy: 0.8626 - loss: 0.6485
# Epoch 4/5
# 60/60 - 3s - 56ms/step - accuracy: 0.9035 - loss: 0.4382
# Epoch 5/5
# 60/60 - 2s - 39ms/step - accuracy: 0.9350 - loss: 0.3089
# 30/30 - 1s - 17ms/step
# Epoch 1/5
# 60/60 - 3s - 53ms/step - accuracy: 0.5957 - loss: 1.8415
# Epoch 2/5
# 60/60 - 3s - 55ms/step - accuracy: 0.7836 - loss: 0.9739
# Epoch 3/5
# 60/60 - 2s - 41ms/step - accuracy: 0.8656 - loss: 0.6337
# Epoch 4/5
# 60/60 - 2s - 39ms/step - accuracy: 0.9107 - loss: 0.4308
# Epoch 5/5
# 60/60 - 2s - 38ms/step - accuracy: 0.9385 - loss: 0.3063
# 30/30 - 1s - 17ms/step
# Epoch 1/5
# 60/60 - 4s - 64ms/step - accuracy: 0.6227 - loss: 1.8403
# Epoch 2/5
# 60/60 - 2s - 39ms/step - accuracy: 0.7827 - loss: 0.9722
# Epoch 3/5
# 60/60 - 2s - 39ms/step - accuracy: 0.8617 - loss: 0.6423
# Epoch 4/5
# 60/60 - 2s - 41ms/step - accuracy: 0.9088 - loss: 0.4362
# Epoch 5/5
# 60/60 - 4s - 58ms/step - accuracy: 0.9375 - loss: 0.3024
# 30/30 - 1s - 18ms/step
# Epoch 1/5
# 60/60 - 3s - 54ms/step - accuracy: 0.6082 - loss: 1.8694
# Epoch 2/5
# 60/60 - 3s - 44ms/step - accuracy: 0.7926 - loss: 0.9621
# Epoch 3/5
# 60/60 - 3s - 55ms/step - accuracy: 0.8627 - loss: 0.6288
# Epoch 4/5
# 60/60 - 4s - 70ms/step - accuracy: 0.9070 - loss: 0.4332
# Epoch 5/5
# 60/60 - 2s - 38ms/step - accuracy: 0.9309 - loss: 0.3114
# 30/30 - 1s - 19ms/step
# Epoch 1/5
# 60/60 - 4s - 63ms/step - accuracy: 0.6202 - loss: 1.8369
# Epoch 2/5
# 60/60 - 2s - 39ms/step - accuracy: 0.7846 - loss: 0.9803
# Epoch 3/5
# 60/60 - 3s - 42ms/step - accuracy: 0.8574 - loss: 0.6500
# Epoch 4/5
# 60/60 - 4s - 64ms/step - accuracy: 0.9048 - loss: 0.4408
# Epoch 5/5
# 60/60 - 4s - 66ms/step - accuracy: 0.9355 - loss: 0.3048
# 30/30 - 1s - 21ms/step
# Epoch 1/5
# 60/60 - 4s - 62ms/step - accuracy: 0.6171 - loss: 1.8364
# Epoch 2/5
# 60/60 - 3s - 55ms/step - accuracy: 0.7829 - loss: 0.9927
# Epoch 3/5
# 60/60 - 2s - 38ms/step - accuracy: 0.8527 - loss: 0.6658
# Epoch 4/5
# 60/60 - 3s - 44ms/step - accuracy: 0.9021 - loss: 0.4516
# Epoch 5/5
# 60/60 - 2s - 36ms/step - accuracy: 0.9350 - loss: 0.3187
# 30/30 - 1s - 17ms/step
# Epoch 1/5
# 90/90 - 5s - 53ms/step - accuracy: 0.6408 - loss: 1.6787
# Epoch 2/5
# 90/90 - 3s - 38ms/step - accuracy: 0.8069 - loss: 0.8695
# Epoch 3/5
# 90/90 - 6s - 67ms/step - accuracy: 0.8769 - loss: 0.5619
# Epoch 4/5
# 90/90 - 4s - 45ms/step - accuracy: 0.9195 - loss: 0.3851
# Epoch 5/5
# 90/90 - 5s - 56ms/step - accuracy: 0.9377 - loss: 0.2895

# %% [markdown]
# <details>
#     <summary>Click here for solution</summary>
#
# ```python
#
# search = RandomizedSearchCV(estimator=base_model, param_distributions=params, cv=3)
# search_result = search.fit(X_train_vec, y_train_hot)
#
# ```
#
# </details>

# %%
print("Best mean cross-validated score: {} using {}".format(round(search_result.best_score_,3), search_result.best_params_))
print("Best test score: %.3f" % search_result.best_estimator_.score(X_test_vec, y_test_hot))
# Out:
# Best mean cross-validated score: 0.799 using {'optimizer__learning_rate': 0.0001, 'optimizer': 'RMSprop', 'dropout_rate': 0.1}
# 23/23 - 1s - 29ms/step
# Best test score: 0.835

# %% [markdown]
# <details>
#     <summary>Click here for solution</summary>
#
# ```python
#
# print("Best mean cross-validated score: {} using {}".format(round(search_result.best_score_,3), search_result.best_params_))
# print("Best test score: %.3f" % search_result.best_estimator_.score(X_test_vec, y_test_hot))
#
# ```
#
# </details>

# %%
# CUSTOM TESTING
import tensorflow as tf
tf.get_logger().setLevel('ERROR')

def create_model(neurons=64, dropout_rate=0.2):
    # Create layers
    model = Sequential()
    model.add(Input(shape=(dim_x,)))
    model.add(Dense(neurons, activation='linear'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(46, activation='softmax'))

    # Compile model
    model.compile(optimizer = 'RMSprop',
                  loss = 'categorical_crossentropy',
                  metrics = ['accuracy'])
    return model

# Set parameters
batch_sizes = [50, 100, 200, 300, 500]
epochs = [3, 5, 7, 9]
neurons = [10, 20, 40, 60]
learning_rates = [1, 0.1, 0.001, 0.0001]
optimizers = ['SGD', 'RMSprop', 'Adam']
dropout_rates = [0.1, 0.3, 0.5, 0.7, 0.9]

params = dict(model__neurons = neurons,
              epochs = epochs,
              batch_size = batch_sizes,
              optimizer = optimizers,
              optimizer__learning_rate = learning_rates,
              model__dropout_rate = dropout_rates)



base_model = KerasClassifier(model = create_model,
                             verbose = 0)


search = RandomizedSearchCV(estimator = base_model,
                            param_distributions = params,
                            cv = 3,
                            n_iter = 8) # default: 10


search_result = search.fit(X_train_vec, y_train_hot)

print("Best mean cross-validated score: {} using {}".format(round(search_result.best_score_,3), search_result.best_params_))
print("Best test score: %.3f" % search_result.best_estimator_.score(X_test_vec, y_test_hot))
# 1st time: 0.813
# 2nd time: 0.829
# Out:
# WARNING:tensorflow:5 out of the last 30 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x785ef9655f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Best mean cross-validated score: 0.794 using {'optimizer__learning_rate': 1, 'optimizer': 'Adam', 'model__neurons': 60, 'model__dropout_rate': 0.3, 'epochs': 7, 'batch_size': 200}
# Best test score: 0.829

# %% [markdown]
# ## Authors

# %% [markdown]
# [Cindy Huang](https://www.linkedin.com/in/cindy-shih-ting-huang/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML311Coursera35714171-2022-01-01) is a data science associate of the Skills Network team. She has a passion for machine learning to improve user experience, especially in the area of computational linguistics.

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# [Contributor with Link](contributor_linl), Contributor No Link

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description |
# | ----------------- | ------- | ---------- | ------------------ |
# | 2022-07-20        | 1.0     | Cindy H.   | Create lab draft   |
# | 2022-09-01        | 1.0     | Steve Hord | QA pass edits      |
# | 2022-11-11        | 1.0     | Shengkai C.| Review and edit    |

# %% [markdown]
# Copyright © 2022 IBM Corporation. All rights reserved.

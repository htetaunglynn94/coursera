# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # **Performing Linear Regression in Keras**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# During the pandemic, a bike-sharing service had suffered considerable losses in their revenues. As a data scientist on the analytics team, you have been tasked to help with coming up with a business plan to accelerate the company's revenue. The first step in this process is to understand the current demand for shared bikes among the people in the city.
#
# You recommend that the team first try to understand the factors on which the demand for these shared bikes depends. In this lab, we will perform a linear regression to predict the count of total rental bikes, and understand the impact of some contributing factors.
#
# <center>
#     <img src="https://live.staticflickr.com/36/84666910_b889a5ad04_b.jpg" width="300" alt="tulip flower">
# <center>

# %% [markdown]
# ## __Table of Contents__
#
# <ol>
#     <li><a href="#Objectives">Objectives</a></li>
#     <li>
#         <a href="#Setup">Setup</a>
#         <ol>
#             <li><a href="#Installing-Required-Libraries">Installing Required Libraries</a></li>
#             <li><a href="#Importing-Required-Libraries">Importing Required Libraries</a></li>
#             <li><a href="#Defining-Helper-Functions">Defining Helper Functions</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="#Linear regression">Linear regression</a>
#         <ol>
#             <li><a href="#Bike-sharing-dataset">Bike sharing dataset</a></li>
#             <li><a href="#Clean-the-data">Clean the data</a></li>
#             <li><a href="#Data-exploration-:-Bivariate-analysis">Data exploration: Bivariate analysis</a></li>
#             <li><a href="#Data exploration-:-Multivariate-analysis">Data exploration: Multivariate analysis</a></li>
#             <li><a href="#Data exploration-:-Heatmap-of-columns">Data exploration: Heatmap of columns</a></li>
#             <li><a href="#Split-the-data-into-training-and-test sets">Split the data into training and test sets</a></li>
#             <li><a href="#Split-features-from-labels">Split features from labels</a></li>
#             <li><a href="#Normalization">Normalization</a></li>
#             <li><a href="#Linear-regression-with-a-single-input">Linear regression with a single input</a></li>
#             <li><a href="#Linear-regression-with-a-multiple-inputs">Linear regression with a multiple inputs</a></li>
#         </ol>
#     </li>
# </ol>
#
# <a href="#Exercises">Exercises</a>
# <ol>
#     <li><a href="#Exercise-1---Loading-a-dataset-(Auto-MPG)">Exercise 1. Loading a dataset (Auto MPG)</a></li>
#     <li><a href="#Exercise-2---Clean-the-data">Exercise 2. Clean the data</a></li>
#     <li><a href="#Exercise-3---Split-the-data">Exercise 3. Split the data</a></li>
#     <li><a href="#Exercise-4---Create-a-normalization-layer">Exercise 4. Create a normalization layer</a></li>
#     <li><a href="#Exercise-5---Linear-regression-with-multiple-inputs">Exercise 5. Linear regression with multiple inputs</a></li>
# </ol>

# %% [markdown]
# ## Objectives
#
# After completing this lab you will be able to:
#
#  - Build single-variable and multi-variable linear regression models using Keras.
#  - Use linear regression to predict a continuous target variable given a set of input features

# %% [markdown]
# ----

# %% [markdown]
# ## Setup

# %% [markdown]
# For this lab, we will be using the following libraries:
#
# *   [`pandas`](https://pandas.pydata.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for managing the data.
# *   [`numpy`](https://numpy.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for mathematical operations.
# *   [`sklearn`](https://scikit-learn.org/stable/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for machine learning and machine-learning-pipeline related functions.
# *   [`seaborn`](https://seaborn.pydata.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for visualizing the data.
# *   [`matplotlib`](https://matplotlib.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for additional plotting tools.

# %% [markdown]
# ### Installing Required Libraries
#
# The following required libraries are pre-installed in the Skills Network Labs environment. However, if you run these notebook commands in a different Jupyter environment (e.g. Watson Studio or Ananconda), you will need to install these libraries by removing the `#` sign before `!pip` in the following code cell.

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented.
# !mamba install -qy pandas==1.3.4 numpy==1.21.4 seaborn==0.9.0 matplotlib==3.5.0 scikit-learn==0.20.1
# Note: If your environment doesn't support "!mamba install", use "!pip install"

# %% [markdown]
# The following required libraries are __not__ pre-installed in the Skills Network Labs environment. __You will need to run the following cell__ to install them:

# %%
# %%capture
# !pip install --upgrade tensorflow

# %% [markdown]
# ### Importing Required Libraries
#
# _We recommend you import all required libraries in one place, as follows:_

# %%
import warnings
warnings.simplefilter('ignore')

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import numpy as np
import pandas as pd
from itertools import accumulate
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Normalization
from tensorflow.keras.optimizers import Adam # Adaptive Moment Estimation (Good for DL)
from tensorflow.keras.optimizers import SGD  # Stochastic Gradient Descent (Traditional)
from sklearn import metrics
from sklearn.metrics import mean_squared_error

sns.set_context('notebook')
sns.set_style('white')

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# Linear Regression models are typically used to study the relationship between a single dependent variable $Y$ and one or more independent variable $X$.
#
# They have an easy-to-interpret mathematical formula that can generate predictions. A simple linear regression model can be used when working with one independent variable, and a multiple regression model can be used when there are more than one independent variables.
#
# We can start with a hypothesis that resembles the line, $Y=\theta_0X+\theta_1$, where $\theta_0$ and $\theta_1$ are the regression coefficients.
#
# Now how do we pick the values of ($\theta_0$) and ($\theta_1$) so that our model predictions are accurate?
#
# We use an optimization method to minimize the loss function so as to reduce the error between model predictions and the ground truth. We start by picking random values of ($\theta_0$) and ($\theta_1$), and continue to update values of the coefficients till convergence. If our loss function stops decreasing, we have reached our local minima.
#
# In multiple linear regression, we use more than one independent features ($X$) and a single dependent feature ($Y$). If we have $n$ features, our formula is as follows. Instead of considering a vector of ($m$) data entries, we will consider the ($n X m$) matrix of $X$.
#
# $Y=\theta_0+\theta_1X_1+\theta_2X_2+\theta_3X_3+...++\theta_nX_n$

# %% [markdown]
# ### Bike sharing dataset
#
# We will be using the bike-sharing dataset from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Bike+Sharing+Dataset?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML311Coursera747-2022-01-01). It contains the following features:
#
# > - instant: record index
# > - dteday : date
# > - season : season (1:winter, 2:spring, 3:summer, 4:fall)
# > - yr : year (0: 2011, 1:2012)
# > - mnth : month ( 1 to 12)
# > - hr : hour (0 to 23)
# > - holiday : weather day is holiday or not (extracted from [Web Link](https://dchr.dc.gov/page/holiday-schedules?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML311Coursera747-2022-01-01))
# > - weekday : day of the week
# > - workingday : if day is neither weekend nor holiday is 1, otherwise is 0.
# > - weathersit :(1) Clear, Few clouds, Partly cloudy, Partly cloudy, (2) Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist, (3) Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds, (4) Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# > - temp : Normalized temperature in Celsius. The values are derived via (t-t_min)/(t_max-t_min), t_min=-8, t_max=+39
# > - atemp: Normalized feeling temperature in Celsius. The values are derived via (t-t_min)/(t_max-t_min), t_min=-16, t_max=+50 (only in hourly scale)
# > hum: Normalized humidity. The values are divided to 100 (max)
# > windspeed: Normalized wind speed. The values are divided to 67 (max)
# > casual: count of casual users
# > registered: count of registered users
# > cnt: count of total rental bikes including both casual and registered

# %% [markdown]
# Download the dataset, and unzip the `Bike-Sharing-Dataset.zip` folder.

# %%
# !pip install skillsnetwork
# Out:
# Collecting skillsnetwork
#   Downloading skillsnetwork-0.21.10-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from skillsnetwork) (7.34.0)
# Requirement already satisfied: ipywidgets<=8.1.3 in /usr/local/lib/python3.12/dist-packages (from skillsnetwork) (7.7.1)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.12/dist-packages (from skillsnetwork) (2.32.4)
# Requirement already satisfied: tqdm<5,>=4 in /usr/local/lib/python3.12/dist-packages (from skillsnetwork) (4.67.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<=8.1.3->skillsnetwork) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<=8.1.3->skillsnetwork) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<=8.1.3->skillsnetwork) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<=8.1.3->skillsnetwork) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<=8.1.3->skillsnetwork) (3.0.15)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython->skillsnetwork) (75.2.0)
# Collecting jedi>=0.16 (from ipython->skillsnetwork)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->skillsnetwork) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->skillsnetwork) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->skillsnetwork) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->skillsnetwork) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->skillsnetwork) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython->skillsnetwork) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->skillsnetwork) (4.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->skillsnetwork) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->skillsnetwork) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->skillsnetwork) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->skillsnetwork) (2025.10.5)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (7.4.9)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (1.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (6.4.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->skillsnetwork) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->skillsnetwork) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->skillsnetwork) (0.2.14)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (6.5.7)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (5.8.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (2.9.0.post0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (3.1.6)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (25.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.23.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.3.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (4.5.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (4.25.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (1.17.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (25.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.27.1)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.12/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (2.14.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (2.0.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (4.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (2.23)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (4.11.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.9.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.3.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (24.11.1)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.3.0)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /usr/local/lib/python3.12/dist-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (2.9.0.20251008)
# Downloading skillsnetwork-0.21.10-py3-none-any.whl (26 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 75.5 MB/s eta 0:00:00
# Installing collected packages: jedi, skillsnetwork
# Successfully installed jedi-0.19.2 skillsnetwork-0.21.10

# %%
import skillsnetwork
await skillsnetwork.prepare("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML311-Coursera/labs/Module1/L2/data/Bike-Sharing-Dataset.zip",overwrite=True)
# Out:
# Downloading Bike-Sharing-Dataset.zip:   0%|          | 0/279992 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
# Saved to '.'

# %% [markdown]
# We will be using the `day.csv` file.

# %%
raw_dataset = pd.read_csv('day.csv')

# %% [markdown]
# Let's look at some samples rows from the dataset we loaded:

# %%
raw_dataset.sample(5)
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 168      169  2011-06-18       2   0     6        0        6           0
# 634      635  2012-09-26       4   1     9        0        3           1
# 675      676  2012-11-06       4   1    11        0        2           1
# 505      506  2012-05-20       2   1     5        0        0           0
# 395      396  2012-01-31       1   1     1        0        2           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 168           1  0.696667  0.643954  0.670417   0.119408    1807        3312
# 634           1  0.635000  0.596613  0.630833   0.244400     787        6946
# 675           1  0.280833  0.281567  0.567083   0.173513     466        5220
# 505           1  0.620833  0.583967  0.530417   0.254367    2704        4425
# 395           1  0.390000  0.381317  0.416667   0.261817     324        4185
#
#       cnt
# 168  5119
# 634  7733
# 675  5686
# 505  7129
# 395  4509

# %% [markdown]
# ### Clean the data

# %% [markdown]
# Let us drop the `dteday` column as it is not numerical, and we already have some other date like features like `mnth`, `year` and `weekday`.
#
# We will remove `instant` as it is just a row instance identifier.
#
# We will also drop `registered` and `casual` as they are used to compute our target variable `cnt` and including them would result in data leakage.

# %%
rmv_cols = ['dteday', 'instant', 'registered', 'casual']
raw_dataset = raw_dataset.drop(columns = rmv_cols)

# %% [markdown]
# ### Data exploration: Bivariate analysis

# %% [markdown]
# We will create scatterplots for a few numerical variables against the target variable `cnt`.

# %%
nu_cols = ['temp','atemp','hum','windspeed'] # numerical columns
plt.figure(figsize=(20,12))
for i in enumerate(nu_cols):
    # print(i)
    plt.subplot(2, 2 ,i[0]+1)
    # Regression plot
    sns.regplot(data=raw_dataset, x=i[1], y='cnt', line_kws={'color':'red'})

plt.show()

# %% [markdown]
# From this, we can infer that there is a positive correlation between `temp` and `atemp` and `cnt`. There is a negative correlation between `windspeed` and `hum` and `cnt`.

# %% [markdown]
# Similarly, we can perform a bivariate analysis on the categorical variables.

# %%
# All categorical columns are decoded as number.
raw_dataset.dtypes
# Out:
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# cnt             int64
# dtype: object

# %%
cols = ['season','yr','mnth','holiday','weekday','workingday','weathersit']
plt.figure(figsize=(20,12))

# Plot correlation based on 2 features
for i in enumerate(cols):
    plt.subplot(2,4,i[0]+1)
    sns.boxplot(data=raw_dataset, x=i[1], y='cnt')

plt.tight_layout()
plt.show()

# season : (1:winter, 2:spring, 3:summer, 4:fall)

# %% [markdown]
# From this we infer that rental bike demands are the highest during Fall and lowest during Spring. There was an increase in demand in bikes in 2019 as compared to 2018. A higher demand for bikes is observed on non-holidays as compared to holidays. Lastly, when renting bikes, clear weather is preferred over light rain, thunderstorm and snowy days.

# %% [markdown]
# ### Data exploration: Multivariate analysis

# %% [markdown]
# We can perform multivariate analysis by creating a pairplot of all the columns in our dataset.

# %%
# Plot based on many features
sns.pairplot(raw_dataset)

# %% [markdown]
# ### Data exploration: Heatmap of columns

# %% [markdown]
# Using a heatmap we can explore which variables are positively or negatively correlated with one another.

# %%
len(raw_dataset.columns)
# Out:
# 12

# %%
plt.figure(figsize=[15,8])
fig = sns.heatmap(raw_dataset.corr(), # Find correlation
                  cmap = 'hot_r',
                  annot = True,
                  linecolor = 'green',
                  lw = 0.01,
                  annot_kws = {'fontsize': 12},
                  fmt = "0.2f")

top, bottom = fig.get_ylim() # 0.0 to 12.0
fig.set_ylim(top+0.1, bottom-0.1)

left, right = fig.get_xlim()
fig.set_xlim(left-0.1, right+0.1)

plt.yticks(fontsize=13,rotation=0)
plt.xticks(fontsize=13,rotation=90)

plt.show()

# %% [markdown]
# From the heatmap, we can infer that `temp` and `atemp` are highly correlated with each other and with `cnt`.
#
# A positive correlation between `temp`, `atemp`, `yr` and `cnt` exists, while a negative correlation between `windspeed`, `hum`, `weathersit`, `holiday` and `cnt` exists.

# %% [markdown]
# ### Split the data into training and test sets

# %% [markdown]
# Now we will split the data set into a training set and a test set. The test set will be used in the final evaluation of your models.

# %%
# 80% train dataset and 20% test dataset
train_dataset = raw_dataset.sample(frac=0.8, random_state=0)
test_dataset = raw_dataset.drop(train_dataset.index)

raw_dataset.shape, train_dataset.shape, test_dataset.shape
# Out:
# ((731, 12), (585, 12), (146, 12))

# %% [markdown]
# ### Split features from labels

# %% [markdown]
# Separate the target value from the features. This label is the value that you will train the model to predict.

# %%
train_features = train_dataset.copy()
test_features = test_dataset.copy()

# %%
train_features = train_dataset.copy()
test_features = test_dataset.copy()

# pop() function do like `inplace=True`
train_labels = train_features.pop('cnt') # get target label for train data
test_labels = test_features.pop('cnt')   # get target label for test data

# %%
train_labels.shape, test_labels.shape
# Out:
# ((585,), (146,))

# %% [markdown]
# ### Normalization

# %% [markdown]
# Since the features in this dataset use different scales and ranges, it is generally considered good practice to normalize the features before performing linear regression. This is partly because the features are multiplied by model weights, and the scale of the outputs and gradients are impacted by that of the inputs. Even though it is possible for the model to converge without any feature normalization, the process of normalization makes the training much more stable.

# %% [markdown]
# We will use `tensorflow.keras.layers.Normalization` as a clean and simple way to add feature normalization to our model.
#
# Let us first create a normalization layer. We will use `axis=-1` as an input argument. As per the [Keras documentation](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Normalization?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML311Coursera747-2022-01-01):
#
# > The axis or axes that should have a separate mean and variance for each index in the shape. For example, if shape is (None, 5) and axis=1, the layer will track 5 separate mean and variance values for the last axis. If axis is set to None, the layer will normalize all elements in the input by a scalar mean and variance. Defaults to -1, where the last axis of the input is assumed to be a feature dimension and is normalized per index.

# %%
normalizer = Normalization(axis=-1) # default

# %% [markdown]
# Now using `normalization.adapt`, we will fit the state of the pre-processing layer to the training data.
#
# This will compute the mean and variance of the data and store them as the layer's weights.

# %%
normalizer.adapt(np.array(train_features))

# %% [markdown]
# Calculate the mean and variance:

# %%
print(normalizer.mean.numpy())
print(normalizer.variance.numpy())
# Out:
# [[2.4820514  0.50598294 6.557265   0.02735043 2.9931624  0.6803419
#   1.4        0.49609548 0.47542128 0.6289289  0.19085288]]
# [[1.2274556e+00 2.4996421e-01 1.1894584e+01 2.6602382e-02 4.0580730e+00
#   2.1747680e-01 2.9811966e-01 3.2840721e-02 2.6041929e-02 2.0187266e-02
#   6.0876710e-03]]

# %% [markdown]
# When the layer is called, it returns the input data, with each feature independently normalized. For example, let us look at the first input row:

# %%
print(np.array(train_features[:1]))
# Out:
# [[3.       0.       7.       0.       6.       0.       1.       0.686667
#   0.638263 0.585    0.208342]]

# %% [markdown]
# Now, let us look at the normalized input:

# %%
normalizer(np.array(train_features[:1])).numpy()
# Out:
# array([[ 0.46750233, -1.0120384 ,  0.12837175, -0.16768873,  1.4926229 ,
#         -1.4588839 , -0.7325962 ,  1.0516028 ,  1.009088  , -0.30918026,
#          0.22415186]], dtype=float32)

# %% [markdown]
# ### Linear regression with a single input

# %% [markdown]
# We can build a linear regression model using one or several variables.

# %% [markdown]
# Let us begin by building a single-variable linear regression to predict `'cnt'` from `'temp'`. We are using `temp` because it is highly correlated with `cnt` and should be highly predictive.
#
# We will use Keras to define a `tf.keras.Sequential` model architecture.
#
# Here are the steps we will follow to create our single-variable linear regression model:
#
# - Using the `tf.keras.layers.Normalization` preprocessing layer that we created earlier, we will normalize the `'temp'` input features.
# - Then we will apply a linear transformation to produce 1 output using a linear layer `tf.keras.layers.Dense`.
#
#
# Note that as per the documentation, the input can either be set by the `input_shape` argument, or automatically when the model is run for the first time.

# %% [markdown]
# Next, we create an array made of the `temp` features.

# %%
temp = np.array(train_features['temp'])
temp.shape
# Out:
# (585,)

# %% [markdown]
# Then we will instantiate the `tf.keras.layers.Normalization` and fit its state to the data like we did before.

# %%
# Create "NNormalization layer in NNs
temp_normalizer = Normalization(input_shape=(1,), axis=None)
# "axis=None" means across the entire dataset

temp_normalizer.adapt(temp) # calculate means and std from temp data

# %% [markdown]
# Build the Keras model:

# %%
temp_model = Sequential([temp_normalizer, Dense(units=1)])
temp_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization_1 (Normalization) │ (None, 1)              │             3 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5 (24.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 3 (16.00 B)

# %% [markdown]
# Now, let us configure the training procedure using `model.compile()`. Here, `loss` is used to define the loss function, which computes the quantity that a model should seek to minimize during training. And `optimizer` defines the optimizer that is used to change weights and learning rate during training to minimize losses.

# %%
temp_model.compile(optimizer = SGD(learning_rate = 0.001),
                   loss = 'mean_squared_error')

# %% [markdown]
# Using `keras.fit`, we train the model for 100 epochs.

# %%
# %%time
history = temp_model.fit(train_features['temp'],
                         train_labels,
                         verbose = 2,
                         epochs = 100,
                         validation_split = 0.2)
# Out:
# Epoch 1/100
# 15/15 - 1s - 56ms/step - loss: 23405512.0000 - val_loss: 23993064.0000
# Epoch 2/100
# 15/15 - 0s - 9ms/step - loss: 22200606.0000 - val_loss: 22732474.0000
# Epoch 3/100
# 15/15 - 0s - 7ms/step - loss: 21068404.0000 - val_loss: 21544492.0000
# Epoch 4/100
# 15/15 - 0s - 7ms/step - loss: 20000624.0000 - val_loss: 20424288.0000
# Epoch 5/100
# 15/15 - 0s - 7ms/step - loss: 18994250.0000 - val_loss: 19364024.0000
# Epoch 6/100
# 15/15 - 0s - 7ms/step - loss: 18040942.0000 - val_loss: 18370868.0000
# Epoch 7/100
# 15/15 - 0s - 7ms/step - loss: 17147374.0000 - val_loss: 17431372.0000
# Epoch 8/100
# 15/15 - 0s - 7ms/step - loss: 16301855.0000 - val_loss: 16542983.0000
# Epoch 9/100
# 15/15 - 0s - 7ms/step - loss: 15504170.0000 - val_loss: 15706720.0000
# Epoch 10/100
# 15/15 - 0s - 7ms/step - loss: 14751724.0000 - val_loss: 14924376.0000
# Epoch 11/100
# 15/15 - 0s - 7ms/step - loss: 14048298.0000 - val_loss: 14182326.0000
# Epoch 12/100
# 15/15 - 0s - 8ms/step - loss: 13381531.0000 - val_loss: 13487032.0000
# Epoch 13/100
# 15/15 - 0s - 7ms/step - loss: 12755833.0000 - val_loss: 12832130.0000
# Epoch 14/100
# 15/15 - 0s - 7ms/step - loss: 12165539.0000 - val_loss: 12211137.0000
# Epoch 15/100
# 15/15 - 0s - 7ms/step - loss: 11606212.0000 - val_loss: 11623367.0000
# Epoch 16/100
# 15/15 - 0s - 7ms/step - loss: 11077893.0000 - val_loss: 11071480.0000
# Epoch 17/100
# 15/15 - 0s - 7ms/step - loss: 10580667.0000 - val_loss: 10555259.0000
# Epoch 18/100
# 15/15 - 0s - 7ms/step - loss: 10114550.0000 - val_loss: 10064571.0000
# Epoch 19/100
# 15/15 - 0s - 7ms/step - loss: 9671859.0000 - val_loss: 9599646.0000
# Epoch 20/100
# 15/15 - 0s - 7ms/step - loss: 9253098.0000 - val_loss: 9165646.0000
# Epoch 21/100
# 15/15 - 0s - 7ms/step - loss: 8862329.0000 - val_loss: 8758028.0000
# Epoch 22/100
# 15/15 - 0s - 7ms/step - loss: 8494502.0000 - val_loss: 8370581.0000
# Epoch 23/100
# 15/15 - 0s - 7ms/step - loss: 8144964.5000 - val_loss: 8004371.0000
# Epoch 24/100
# 15/15 - 0s - 7ms/step - loss: 7814860.5000 - val_loss: 7660928.5000
# Epoch 25/100
# 15/15 - 0s - 7ms/step - loss: 7504533.0000 - val_loss: 7338493.5000
# Epoch 26/100
# 15/15 - 0s - 7ms/step - loss: 7213113.0000 - val_loss: 7033590.5000
# Epoch 27/100
# 15/15 - 0s - 7ms/step - loss: 6937588.5000 - val_loss: 6747425.0000
# Epoch 28/100
# 15/15 - 0s - 7ms/step - loss: 6678724.0000 - val_loss: 6475572.5000
# Epoch 29/100
# 15/15 - 0s - 7ms/step - loss: 6432418.5000 - val_loss: 6221348.0000
# Epoch 30/100
# 15/15 - 0s - 7ms/step - loss: 6201848.5000 - val_loss: 5978682.5000
# Epoch 31/100
# 15/15 - 0s - 7ms/step - loss: 5982165.0000 - val_loss: 5752864.5000
# Epoch 32/100
# 15/15 - 0s - 9ms/step - loss: 5777403.0000 - val_loss: 5538954.5000
# Epoch 33/100
# 15/15 - 0s - 11ms/step - loss: 5583294.5000 - val_loss: 5336820.0000
# Epoch 34/100
# 15/15 - 0s - 12ms/step - loss: 5399703.0000 - val_loss: 5147474.0000
# Epoch 35/100
# 15/15 - 0s - 10ms/step - loss: 5227461.0000 - val_loss: 4970968.5000
# Epoch 36/100
# 15/15 - 0s - 10ms/step - loss: 5066689.0000 - val_loss: 4802938.5000
# Epoch 37/100
# 15/15 - 0s - 23ms/step - loss: 4913742.0000 - val_loss: 4644326.5000
# Epoch 38/100
# 15/15 - 0s - 12ms/step - loss: 4769561.0000 - val_loss: 4495176.5000
# Epoch 39/100
# 15/15 - 0s - 13ms/step - loss: 4633441.0000 - val_loss: 4354266.5000
# Epoch 40/100
# 15/15 - 0s - 11ms/step - loss: 4504638.5000 - val_loss: 4220876.0000
# Epoch 41/100
# 15/15 - 0s - 13ms/step - loss: 4382800.5000 - val_loss: 4095574.7500
# Epoch 42/100
# 15/15 - 0s - 8ms/step - loss: 4268207.5000 - val_loss: 3977671.7500
# Epoch 43/100
# 15/15 - 0s - 7ms/step - loss: 4159940.5000 - val_loss: 3867051.5000
# Epoch 44/100
# 15/15 - 0s - 7ms/step - loss: 4058527.2500 - val_loss: 3760948.7500
# Epoch 45/100
# 15/15 - 0s - 9ms/step - loss: 3961058.7500 - val_loss: 3663182.5000
# Epoch 46/100
# 15/15 - 0s - 7ms/step - loss: 3871451.2500 - val_loss: 3572000.2500
# Epoch 47/100
# 15/15 - 0s - 7ms/step - loss: 3787255.5000 - val_loss: 3485515.2500
# Epoch 48/100
# 15/15 - 0s - 7ms/step - loss: 3707407.0000 - val_loss: 3402658.5000
# Epoch 49/100
# 15/15 - 0s - 7ms/step - loss: 3630933.2500 - val_loss: 3325234.2500
# Epoch 50/100
# 15/15 - 0s - 7ms/step - loss: 3559543.2500 - val_loss: 3253531.5000
# Epoch 51/100
# 15/15 - 0s - 7ms/step - loss: 3492946.0000 - val_loss: 3185026.2500
# Epoch 52/100
# 15/15 - 0s - 8ms/step - loss: 3429479.7500 - val_loss: 3119669.0000
# Epoch 53/100
# 15/15 - 0s - 7ms/step - loss: 3368815.7500 - val_loss: 3059230.2500
# Epoch 54/100
# 15/15 - 0s - 7ms/step - loss: 3312682.5000 - val_loss: 3002080.0000
# Epoch 55/100
# 15/15 - 0s - 7ms/step - loss: 3259411.2500 - val_loss: 2947172.5000
# Epoch 56/100
# 15/15 - 0s - 7ms/step - loss: 3208074.5000 - val_loss: 2896686.0000
# Epoch 57/100
# 15/15 - 0s - 7ms/step - loss: 3160939.5000 - val_loss: 2848998.2500
# Epoch 58/100
# 15/15 - 0s - 7ms/step - loss: 3115854.0000 - val_loss: 2803850.0000
# Epoch 59/100
# 15/15 - 0s - 9ms/step - loss: 3073441.0000 - val_loss: 2762214.2500
# Epoch 60/100
# 15/15 - 0s - 7ms/step - loss: 3034041.5000 - val_loss: 2722481.7500
# Epoch 61/100
# 15/15 - 0s - 8ms/step - loss: 2996565.5000 - val_loss: 2685278.7500
# Epoch 62/100
# 15/15 - 0s - 7ms/step - loss: 2961358.5000 - val_loss: 2650003.5000
# Epoch 63/100
# 15/15 - 0s - 7ms/step - loss: 2928006.0000 - val_loss: 2617445.0000
# Epoch 64/100
# 15/15 - 0s - 9ms/step - loss: 2897058.0000 - val_loss: 2586376.7500
# Epoch 65/100
# 15/15 - 0s - 7ms/step - loss: 2867481.7500 - val_loss: 2557575.5000
# Epoch 66/100
# 15/15 - 0s - 7ms/step - loss: 2839855.5000 - val_loss: 2529908.0000
# Epoch 67/100
# 15/15 - 0s - 7ms/step - loss: 2813415.0000 - val_loss: 2504511.5000
# Epoch 68/100
# 15/15 - 0s - 7ms/step - loss: 2788994.7500 - val_loss: 2480473.5000
# Epoch 69/100
# 15/15 - 0s - 7ms/step - loss: 2765784.0000 - val_loss: 2457682.7500
# Epoch 70/100
# 15/15 - 0s - 7ms/step - loss: 2743889.0000 - val_loss: 2436436.7500
# Epoch 71/100
# 15/15 - 0s - 8ms/step - loss: 2723160.2500 - val_loss: 2416210.0000
# Epoch 72/100
# 15/15 - 0s - 7ms/step - loss: 2703380.5000 - val_loss: 2397218.7500
# Epoch 73/100
# 15/15 - 0s - 7ms/step - loss: 2684863.5000 - val_loss: 2379770.7500
# Epoch 74/100
# 15/15 - 0s - 7ms/step - loss: 2667689.0000 - val_loss: 2363263.0000
# Epoch 75/100
# 15/15 - 0s - 8ms/step - loss: 2651360.0000 - val_loss: 2347257.5000
# Epoch 76/100
# 15/15 - 0s - 7ms/step - loss: 2635666.0000 - val_loss: 2332775.5000
# Epoch 77/100
# 15/15 - 0s - 7ms/step - loss: 2621186.7500 - val_loss: 2318645.0000
# Epoch 78/100
# 15/15 - 0s - 7ms/step - loss: 2607177.7500 - val_loss: 2305591.2500
# Epoch 79/100
# 15/15 - 0s - 7ms/step - loss: 2594199.2500 - val_loss: 2293175.2500
# Epoch 80/100
# 15/15 - 0s - 7ms/step - loss: 2581603.0000 - val_loss: 2281511.5000
# Epoch 81/100
# 15/15 - 0s - 7ms/step - loss: 2569720.0000 - val_loss: 2270601.0000
# Epoch 82/100
# 15/15 - 0s - 7ms/step - loss: 2558735.0000 - val_loss: 2260622.2500
# Epoch 83/100
# 15/15 - 0s - 7ms/step - loss: 2548478.7500 - val_loss: 2251297.7500
# Epoch 84/100
# 15/15 - 0s - 7ms/step - loss: 2539016.2500 - val_loss: 2243031.0000
# Epoch 85/100
# 15/15 - 0s - 7ms/step - loss: 2530296.5000 - val_loss: 2234948.7500
# Epoch 86/100
# 15/15 - 0s - 7ms/step - loss: 2521985.2500 - val_loss: 2227377.0000
# Epoch 87/100
# 15/15 - 0s - 7ms/step - loss: 2514291.7500 - val_loss: 2220261.5000
# Epoch 88/100
# 15/15 - 0s - 7ms/step - loss: 2506717.5000 - val_loss: 2213401.7500
# Epoch 89/100
# 15/15 - 0s - 9ms/step - loss: 2499564.0000 - val_loss: 2206998.0000
# Epoch 90/100
# 15/15 - 0s - 8ms/step - loss: 2492689.5000 - val_loss: 2201087.2500
# Epoch 91/100
# 15/15 - 0s - 7ms/step - loss: 2486486.5000 - val_loss: 2195758.2500
# Epoch 92/100
# 15/15 - 0s - 7ms/step - loss: 2480614.5000 - val_loss: 2190126.0000
# Epoch 93/100
# 15/15 - 0s - 7ms/step - loss: 2474322.2500 - val_loss: 2185080.0000
# Epoch 94/100
# 15/15 - 0s - 7ms/step - loss: 2468869.5000 - val_loss: 2180534.2500
# Epoch 95/100
# 15/15 - 0s - 7ms/step - loss: 2463942.7500 - val_loss: 2176266.2500
# Epoch 96/100
# 15/15 - 0s - 7ms/step - loss: 2459190.7500 - val_loss: 2172244.5000
# Epoch 97/100
# 15/15 - 0s - 7ms/step - loss: 2454525.5000 - val_loss: 2168514.0000
# Epoch 98/100
# 15/15 - 0s - 7ms/step - loss: 2450299.0000 - val_loss: 2165017.0000
# Epoch 99/100
# 15/15 - 0s - 7ms/step - loss: 2446376.5000 - val_loss: 2161459.7500
# Epoch 100/100
# 15/15 - 0s - 7ms/step - loss: 2442300.7500 - val_loss: 2158457.5000
# CPU times: user 12.3 s, sys: 777 ms, total: 13 s
# Wall time: 12.5 s

# %% [markdown]
# We can create a plot of loss on the training and validation datasets over training epochs.

# %%
def plot_loss(history):
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
plot_loss(history)

# %% [markdown]
# Next, we will use `model.predict` to predict the `cnt` values in the test dataset, using just the `temp` feature values as input:

# %%
y_pred = temp_model.predict(test_features['temp'])
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step

# %% [markdown]
# We can compute the root mean squared error:

# %%
np.sqrt(metrics.mean_squared_error(test_labels, y_pred)) # square-root to MSE
# Out:
# np.float64(1437.0449714605315)

# %% [markdown]
# Since this a single-variable linear regression, we can easily visualize the results:

# %%
plt.figure(figsize=(4,4))
plt.plot(
            test_features['temp'], test_labels, 'o', # for 1st plot
            test_features['temp'], temp_model.predict(test_features['temp']), 'g' # for 2nd plot
        )
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
sns.regplot(x=test_features['temp'], y=test_labels)
# Out:
# <Axes: xlabel='temp', ylabel='cnt'>

# %% [markdown]
# ### Linear regression with multiple inputs

# %% [markdown]
# We will create a similar setup to predict `cnt` based on multiple inputs. In this case, in our $y = mx+b$ equation, $m$ will be a matrix and $b$ will be a vector.
#
# Similar to what we did before, the Sequential model will have `normalizer` as the first layer, and `Dense` as the second layer:

# %%
linear_model = Sequential([normalizer, Dense(units=1)])
linear_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)   │ (585, 11)              │            23 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23 (96.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 23 (96.00 B)

# %% [markdown]
# We will compile the model using `complie()` and train the model on 100 epochs using `fit()`:

# %%
linear_model.compile(optimizer = SGD(learning_rate = 0.001),
                     loss = 'mean_squared_error')

# %%
train_features.sample(5)
# Out:
#      season  yr  mnth  holiday  weekday  workingday  weathersit      temp  \
# 425       1   1     3        0        4           1           1  0.485833
# 587       3   1     8        0        5           1           2  0.715833
# 118       2   0     4        0        5           1           1  0.510000
# 540       3   1     6        0        0           0           1  0.743333
# 518       2   1     6        0        6           0           1  0.583333
#
#         atemp       hum  windspeed
# 425  0.475371  0.615417   0.226987
# 587  0.667942  0.715833   0.238813
# 118  0.497463  0.457083   0.240063
# 540  0.674254  0.479167   0.145525
# 518  0.566288  0.549167   0.186562

# %%
train_labels.sample(5)
# Out:
# 108    3204
# 249    1996
# 106    3744
# 621    7804
# 0       985
# Name: cnt, dtype: int64

# %%
# %%time
history = linear_model.fit(train_features,
                           train_labels,
                           epochs=100,
                           verbose = 0,
                           validation_split = 0.2) # 20% of training data
# Out:
# CPU times: user 11.8 s, sys: 732 ms, total: 12.5 s
# Wall time: 11.9 s

# %%
plot_loss(history)

# %% [markdown]
# We can see that with all the inputs in the regression model, it achieves a much lower training and validation error, and RMSE than the `temp_model` that had just one input.

# %%
y_pred = linear_model.predict(test_features)
print(np.sqrt(metrics.mean_squared_error(test_labels, y_pred))) # RMSE
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 902.64074387322

# %% [markdown]
# `get_weights` returns a list consisting of NumPy arrays. The first array gives the weights of the layer and the second array gives the biases.

# %%
# Print column names for reference
print("Column names")
print(test_features.columns)
# Out:
# Column names
# Index(['season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed'],
#       dtype='object')

# %%
# Print weights and biases for each layer
for layer in linear_model.layers:
    print("Layer Name:", layer.name)
    print("---")
    print("Weights")
    print("Shape:", layer.get_weights()[0].shape, '\n', layer.get_weights()[0])
    print("---")
    print("Bias")
    print("Shape:", layer.get_weights()[1].shape, '\n', layer.get_weights()[1], '\n')
# Out:
# Layer Name: normalization
# ---
# Weights
# Shape: (11,)
#  [2.4820514  0.50598294 6.557265   0.02735043 2.9931624  0.6803419
#  1.4        0.49609548 0.47542128 0.6289289  0.19085288]
# ---
# Bias
# Shape: (11,)
#  [1.2274556e+00 2.4996421e-01 1.1894584e+01 2.6602382e-02 4.0580730e+00
#  2.1747680e-01 2.9811966e-01 3.2840721e-02 2.6041929e-02 2.0187266e-02
#  6.0876710e-03]
#
# Layer Name: dense_2
# ---
# Weights
# Shape: (11, 1)
#  [[ 361.60834 ]
#  [ 993.22504 ]
#  [  48.434586]
#  [-137.08614 ]
#  [ 157.0663  ]
#  [  77.28889 ]
#  [-356.2887  ]
#  [ 477.0906  ]
#  [ 512.70435 ]
#  [-164.7787  ]
#  [-213.29187 ]]
# ---
# Bias
# Shape: (1,)
#  [4292.9136]

# %% [markdown]
# From the model weights, we can see that, similar to what we had seen in our heatmap, `yr`, `temp` and `atemp` have the highest model weights, and hence contribute the most the `cnt` predictions.

# %% [markdown]
# ## Using Neural Networks for Linear Regression

# %% [markdown]
# In this section, we will use a Neural Network architecture in Keras to perform simple linear regression.

# %% [markdown]
# Let us begin by reading our univariate dataset. We will use the Iowa Housing dataset where the only feature is SquareFeet, and the target value is SalePrice.

# %% [markdown]
# We will reserve the last 500 data points for testing purposes.

# %%
url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML311-Coursera/labs/Module1/L2/data/IowaHousingPrices.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    SquareFeet  SalePrice
# 0        1710     208500
# 1        1262     181500
# 2        1786     223500
# 3        1717     140000
# 4        2198     250000

# %%
X_train = df[['SquareFeet']].values[1:-500]
y_train = df[['SalePrice']].values[1:-500]
X_test  = df[['SquareFeet']].values[-500:]
y_test  = df[['SalePrice']].values[-500:]

# %% [markdown]
# Now, we'll define the model configuration parameters. Since we're dealing with a univariate dataset, both our input and output sizes are 1. The learning rate is selected arbitrarily, where the goal is to ensure the NN doesn't overfit to the training data, and is easily generalizable to unseen test sets. We will use mean squared error as the loss function, and train the model on 30 iterations.

# %%
output_size = 1 # one output
hidden_layer = 500
input_size = 1 # one input
learning_rate = 0.51 # selected arbitrarily
loss_function = 'mean_squared_error'
epochs = 30
batch_size = 10

# %% [markdown]
# We will create a `Sequential` model and add a Dense layer with a relu activation in the hidden layer with ```hidden_layer``` neurons. As we have one output the output layer will have a dimension of  one.

# %%
import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(hidden_layer, activation='relu')) # Rectified Linear Unit
model.add(Dense(output_size))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Next, we will compile and fit the model based on the configuration parameters defined earlier.

# %%
model.compile(optimizer = Adam(learning_rate=learning_rate),
              loss = loss_function)

# %%
model.fit(X_train, y_train,
          epochs = epochs,
          batch_size = batch_size)
# Out:
# Epoch 1/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 11830003712.0000
# Epoch 2/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3493686784.0000
# Epoch 3/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3799321856.0000
# Epoch 4/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4905384960.0000
# Epoch 5/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4325252608.0000
# Epoch 6/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3025884928.0000
# Epoch 7/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3094263296.0000
# Epoch 8/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3154686976.0000
# Epoch 9/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3495312384.0000
# Epoch 10/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2808060928.0000
# Epoch 11/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3433312768.0000
# Epoch 12/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3460103680.0000
# Epoch 13/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3653322752.0000
# Epoch 14/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3360587776.0000
# Epoch 15/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3428538368.0000
# Epoch 16/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3463956992.0000
# Epoch 17/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3230246912.0000
# Epoch 18/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3696836096.0000
# Epoch 19/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3652467712.0000
# Epoch 20/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3470138624.0000
# Epoch 21/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2680966656.0000
# Epoch 22/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3143916032.0000
# Epoch 23/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3468225536.0000
# Epoch 24/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3434192640.0000
# Epoch 25/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2876077312.0000
# Epoch 26/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3815499520.0000
# Epoch 27/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2835222784.0000
# Epoch 28/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3810399744.0000
# Epoch 29/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3505612032.0000
# Epoch 30/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3780921344.0000

# %% [markdown]
# Let us predict the sales prices on the full range of the test set and plot the result.

# %%
X_test.min(), X_test.max()
# Out:
# (np.int64(438), np.int64(5642))

# %%
np.arange(X_test.min(), X_test.max(), 10).shape
# Out:
# (521,)

# %%
x = np.arange(X_test.min(), X_test.max(), 10).reshape(-1,1)
x.shape
# Out:
# (521, 1)

# %%
y_pred = model.predict(x)
y_pred.shape
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# (521, 1)

# %%
plt.plot(X_test, y_test, 'ro', label='test samples')
plt.plot(x, y_pred, label='prediction')
plt.xlabel('input')
plt.ylabel('predicted output')
plt.legend()
plt.show()

# %% [markdown]
# The model performs relatively well on the test set.

# %% [markdown]
# # Exercises

# %% [markdown]
# In this section, you will train a linear regression model in Keras. We will be using the classic Auto MPG dataset, and predict the fiel efficiency of automobiles.

# %% [markdown]
# ### Exercise 1 - Loading a dataset (Auto MPG)

# %% [markdown]
# The dataset is again found in the UCI Machine Learning Repository. You can download it from [here](http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML311Coursera747-2022-01-01).

# %%
url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML311-Coursera/labs/Module1/L2/data/auto-mpg.data'
col_names = ['MPG','Cylinders','Displacement','Horsepower','Weight','Acceleration','Model Year','Origin']
# Without parameters
raw_dataset = pd.read_csv(url, names=col_names)
raw_dataset.head()
# Out:
#                                                  MPG  Cylinders  Displacement  \
# 0  18.0   8   307.0      130.0      3504.      12...        NaN           NaN
# 1  15.0   8   350.0      165.0      3693.      11...        NaN           NaN
# 2  18.0   8   318.0      150.0      3436.      11...        NaN           NaN
# 3  16.0   8   304.0      150.0      3433.      12...        NaN           NaN
# 4  17.0   8   302.0      140.0      3449.      10...        NaN           NaN
#
#    Horsepower  Weight  Acceleration  Model Year  Origin
# 0         NaN     NaN           NaN         NaN     NaN
# 1         NaN     NaN           NaN         NaN     NaN
# 2         NaN     NaN           NaN         NaN     NaN
# 3         NaN     NaN           NaN         NaN     NaN
# 4         NaN     NaN           NaN         NaN     NaN

# %%
url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML311-Coursera/labs/Module1/L2/data/auto-mpg.data'
col_names = ['MPG','Cylinders','Displacement','Horsepower','Weight','Acceleration','Model Year','Origin']
# With parameters
raw_dataset = pd.read_csv(url,
                          names = col_names,       # column names
                          na_values = '?',         # missing values represent as "?"
                          sep = ' ',               # space separated data
                          comment = '\t',          # random comment in file
                          skipinitialspace = True) # extra space around values
raw_dataset.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    Model Year  Origin
# 0          70       1
# 1          70       1
# 2          70       1
# 3          70       1
# 4          70       1

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# raw_dataset = pd.read_csv(url, names=column_names,
#                           na_values='?', comment='\t',
#                           sep=' ', skipinitialspace=True)
# ```
#
# </details>

# %% [markdown]
# ### Exercise 2 - Clean the data

# %% [markdown]
# Drop all the rows that have NA values, and remove the `origin` column as it is categorical.

# %%
dataset = raw_dataset.dropna(axis=0)
dataset.drop(columns=['Origin'], inplace=True)

# %%
dataset.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year
# 0  18.0          8         307.0       130.0  3504.0          12.0          70
# 1  15.0          8         350.0       165.0  3693.0          11.5          70
# 2  18.0          8         318.0       150.0  3436.0          11.0          70
# 3  16.0          8         304.0       150.0  3433.0          12.0          70
# 4  17.0          8         302.0       140.0  3449.0          10.5          70

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# dataset = raw_dataset.dropna()
# dataset = dataset.drop(columns=['Origin'])
# ```
#
# </details>

# %% [markdown]
# ### Exercise 3 - Split the data

# %% [markdown]
# Split the data into training and test, and split the target from features.

# %%
train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)

train_features = train_dataset.copy() # input data for training
test_features = test_dataset.copy()   # input data for testing

train_labels = train_features.pop('MPG') # target data for training
test_labels = test_features.pop('MPG')   # target data for testing

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# train_dataset = dataset.sample(frac=0.8, random_state=0)
# test_dataset = dataset.drop(train_dataset.index)
#
# train_features = train_dataset.copy()
# test_features = test_dataset.copy()
#
# train_labels = train_features.pop('MPG')
# test_labels = test_features.pop('MPG')
# ```
#
# </details>

# %% [markdown]
# ### Exercise 4 - Create a normalization layer

# %% [markdown]
# Next, use `tf.keras.layers.Normalization` to add feature normalization to the model. Using `normalization.adapt`, fit the state of the pre-processing layer to the training data. Calculate and print the mean and variance.

# %%
normalizer = Normalization(axis=-1)
normalizer.adapt(np.array(train_features))
print(normalizer.mean.numpy()) # mean value of each features
print(normalizer.variance.numpy()) # data spreading
# Out:
# [[   5.477707  195.31847   104.86943  2990.2517     15.559236   75.89809 ]]
# [[2.8800762e+00 1.0850414e+04 1.4466995e+03 7.0989681e+05 7.7550263e+00
#   1.3467321e+01]]

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# normalizer = tf.keras.layers.Normalization(axis=-1)
# normalizer.adapt(np.array(train_features))
# print(normalizer.mean.numpy())
# print(normalizer.variance.numpy())
# ```
#
# </details>

# %% [markdown]
# ### Exercise 5 - Linear regression with multiple inputs

# %% [markdown]
# Create a linear regression model to predict `MPG` based on all inputs in the dataset. In this case, in our $y = mx+b$ equation, $m$ will be a matrix and $b$ will be a vector.
#
# Similar to what we did before, the Sequential model will have `normalizer` as the first layer, and `Dense` as the second layer. Compile and train the model, and plot the training history.

# %%
lr_model = Sequential([normalizer, Dense(units=1)])

lr_model.compile(optimizer = SGD(learning_rate = 1e-3),
                 loss = 'mean_squared_error')

# %%
lr_model = keras.Sequential([
                             normalizer,
                             Dense(units=1)
                            ])

lr_model.compile(optimizer=SGD(learning_rate = 1e-3),
                 loss='mean_squared_error')

history = lr_model.fit(train_features,
                       train_labels,
                       epochs = 100,
                       verbose = 2,
                       validation_split = 0.2)

plot_loss(history)
# Out:
# Epoch 1/100
# 8/8 - 1s - 118ms/step - loss: 607.7816 - val_loss: 625.2603
# Epoch 2/100
# 8/8 - 0s - 11ms/step - loss: 583.5638 - val_loss: 599.9994
# Epoch 3/100
# 8/8 - 0s - 11ms/step - loss: 560.6955 - val_loss: 576.4142
# Epoch 4/100
# 8/8 - 0s - 10ms/step - loss: 539.2831 - val_loss: 554.3474
# Epoch 5/100
# 8/8 - 0s - 11ms/step - loss: 519.0637 - val_loss: 533.4714
# Epoch 6/100
# 8/8 - 0s - 10ms/step - loss: 499.9205 - val_loss: 513.7883
# Epoch 7/100
# 8/8 - 0s - 10ms/step - loss: 481.8690 - val_loss: 495.2499
# Epoch 8/100
# 8/8 - 0s - 10ms/step - loss: 464.7279 - val_loss: 477.5220
# Epoch 9/100
# 8/8 - 0s - 10ms/step - loss: 448.2599 - val_loss: 460.5945
# Epoch 10/100
# 8/8 - 0s - 10ms/step - loss: 432.5677 - val_loss: 444.6528
# Epoch 11/100
# 8/8 - 0s - 11ms/step - loss: 417.6447 - val_loss: 429.4617
# Epoch 12/100
# 8/8 - 0s - 10ms/step - loss: 403.4734 - val_loss: 414.9161
# Epoch 13/100
# 8/8 - 0s - 12ms/step - loss: 389.7980 - val_loss: 401.0544
# Epoch 14/100
# 8/8 - 0s - 10ms/step - loss: 376.7818 - val_loss: 387.7430
# Epoch 15/100
# 8/8 - 0s - 10ms/step - loss: 364.2735 - val_loss: 375.0795
# Epoch 16/100
# 8/8 - 0s - 17ms/step - loss: 352.4916 - val_loss: 362.9081
# Epoch 17/100
# 8/8 - 0s - 16ms/step - loss: 340.8652 - val_loss: 351.3113
# Epoch 18/100
# 8/8 - 0s - 19ms/step - loss: 330.0062 - val_loss: 340.1865
# Epoch 19/100
# 8/8 - 0s - 15ms/step - loss: 319.4283 - val_loss: 329.4805
# Epoch 20/100
# 8/8 - 0s - 15ms/step - loss: 309.2575 - val_loss: 319.1298
# Epoch 21/100
# 8/8 - 0s - 20ms/step - loss: 299.5023 - val_loss: 309.2254
# Epoch 22/100
# 8/8 - 0s - 19ms/step - loss: 290.0499 - val_loss: 299.7087
# Epoch 23/100
# 8/8 - 0s - 14ms/step - loss: 280.9804 - val_loss: 290.4708
# Epoch 24/100
# 8/8 - 0s - 19ms/step - loss: 272.1831 - val_loss: 281.5883
# Epoch 25/100
# 8/8 - 0s - 16ms/step - loss: 263.7420 - val_loss: 273.0165
# Epoch 26/100
# 8/8 - 0s - 21ms/step - loss: 255.5764 - val_loss: 264.7567
# Epoch 27/100
# 8/8 - 0s - 20ms/step - loss: 247.7342 - val_loss: 256.8051
# Epoch 28/100
# 8/8 - 0s - 29ms/step - loss: 240.1531 - val_loss: 249.0994
# Epoch 29/100
# 8/8 - 0s - 10ms/step - loss: 232.8075 - val_loss: 241.6790
# Epoch 30/100
# 8/8 - 0s - 11ms/step - loss: 225.7382 - val_loss: 234.5334
# Epoch 31/100
# 8/8 - 0s - 10ms/step - loss: 218.9728 - val_loss: 227.5817
# Epoch 32/100
# 8/8 - 0s - 10ms/step - loss: 212.3781 - val_loss: 220.8911
# Epoch 33/100
# 8/8 - 0s - 11ms/step - loss: 205.9431 - val_loss: 214.4093
# Epoch 34/100
# 8/8 - 0s - 10ms/step - loss: 199.7370 - val_loss: 208.1535
# Epoch 35/100
# 8/8 - 0s - 10ms/step - loss: 193.8064 - val_loss: 202.0943
# Epoch 36/100
# 8/8 - 0s - 10ms/step - loss: 188.0463 - val_loss: 196.2352
# Epoch 37/100
# 8/8 - 0s - 10ms/step - loss: 182.4699 - val_loss: 190.5785
# Epoch 38/100
# 8/8 - 0s - 10ms/step - loss: 177.0743 - val_loss: 185.0944
# Epoch 39/100
# 8/8 - 0s - 12ms/step - loss: 171.8462 - val_loss: 179.7792
# Epoch 40/100
# 8/8 - 0s - 10ms/step - loss: 166.7966 - val_loss: 174.6452
# Epoch 41/100
# 8/8 - 0s - 11ms/step - loss: 161.9350 - val_loss: 169.6632
# Epoch 42/100
# 8/8 - 0s - 11ms/step - loss: 157.2040 - val_loss: 164.8449
# Epoch 43/100
# 8/8 - 0s - 10ms/step - loss: 152.6424 - val_loss: 160.1714
# Epoch 44/100
# 8/8 - 0s - 11ms/step - loss: 148.1840 - val_loss: 155.6631
# Epoch 45/100
# 8/8 - 0s - 11ms/step - loss: 143.8970 - val_loss: 151.2841
# Epoch 46/100
# 8/8 - 0s - 10ms/step - loss: 139.7452 - val_loss: 147.0620
# Epoch 47/100
# 8/8 - 0s - 10ms/step - loss: 135.7743 - val_loss: 142.9563
# Epoch 48/100
# 8/8 - 0s - 11ms/step - loss: 131.8515 - val_loss: 138.9797
# Epoch 49/100
# 8/8 - 0s - 11ms/step - loss: 128.0769 - val_loss: 135.1258
# Epoch 50/100
# 8/8 - 0s - 16ms/step - loss: 124.4282 - val_loss: 131.3969
# Epoch 51/100
# 8/8 - 0s - 12ms/step - loss: 120.9141 - val_loss: 127.7872
# Epoch 52/100
# 8/8 - 0s - 10ms/step - loss: 117.4800 - val_loss: 124.2875
# Epoch 53/100
# 8/8 - 0s - 11ms/step - loss: 114.1925 - val_loss: 120.8950
# Epoch 54/100
# 8/8 - 0s - 11ms/step - loss: 110.9684 - val_loss: 117.6166
# Epoch 55/100
# 8/8 - 0s - 10ms/step - loss: 107.9026 - val_loss: 114.4345
# Epoch 56/100
# 8/8 - 0s - 10ms/step - loss: 104.8958 - val_loss: 111.3514
# Epoch 57/100
# 8/8 - 0s - 11ms/step - loss: 102.0159 - val_loss: 108.3627
# Epoch 58/100
# 8/8 - 0s - 11ms/step - loss: 99.1860 - val_loss: 105.4610
# Epoch 59/100
# 8/8 - 0s - 10ms/step - loss: 96.4560 - val_loss: 102.6504
# Epoch 60/100
# 8/8 - 0s - 11ms/step - loss: 93.8164 - val_loss: 99.9269
# Epoch 61/100
# 8/8 - 0s - 11ms/step - loss: 91.2437 - val_loss: 97.2858
# Epoch 62/100
# 8/8 - 0s - 12ms/step - loss: 88.7859 - val_loss: 94.7316
# Epoch 63/100
# 8/8 - 0s - 11ms/step - loss: 86.4466 - val_loss: 92.2564
# Epoch 64/100
# 8/8 - 0s - 11ms/step - loss: 84.0637 - val_loss: 89.8541
# Epoch 65/100
# 8/8 - 0s - 11ms/step - loss: 81.8275 - val_loss: 87.5258
# Epoch 66/100
# 8/8 - 0s - 11ms/step - loss: 79.6389 - val_loss: 85.2668
# Epoch 67/100
# 8/8 - 0s - 11ms/step - loss: 77.5284 - val_loss: 83.0742
# Epoch 68/100
# 8/8 - 0s - 10ms/step - loss: 75.5137 - val_loss: 80.9537
# Epoch 69/100
# 8/8 - 0s - 11ms/step - loss: 73.5384 - val_loss: 78.8993
# Epoch 70/100
# 8/8 - 0s - 10ms/step - loss: 71.6018 - val_loss: 76.9032
# Epoch 71/100
# 8/8 - 0s - 11ms/step - loss: 69.7427 - val_loss: 74.9641
# Epoch 72/100
# 8/8 - 0s - 11ms/step - loss: 67.9454 - val_loss: 73.0878
# Epoch 73/100
# 8/8 - 0s - 13ms/step - loss: 66.2185 - val_loss: 71.2774
# Epoch 74/100
# 8/8 - 0s - 11ms/step - loss: 64.5226 - val_loss: 69.5204
# Epoch 75/100
# 8/8 - 0s - 11ms/step - loss: 62.8999 - val_loss: 67.8137
# Epoch 76/100
# 8/8 - 0s - 11ms/step - loss: 61.3330 - val_loss: 66.1544
# Epoch 77/100
# 8/8 - 0s - 10ms/step - loss: 59.7945 - val_loss: 64.5488
# Epoch 78/100
# 8/8 - 0s - 11ms/step - loss: 58.3171 - val_loss: 62.9927
# Epoch 79/100
# 8/8 - 0s - 10ms/step - loss: 56.8772 - val_loss: 61.4868
# Epoch 80/100
# 8/8 - 0s - 10ms/step - loss: 55.4905 - val_loss: 60.0171
# Epoch 81/100
# 8/8 - 0s - 12ms/step - loss: 54.1322 - val_loss: 58.5942
# Epoch 82/100
# 8/8 - 0s - 10ms/step - loss: 52.8253 - val_loss: 57.2231
# Epoch 83/100
# 8/8 - 0s - 11ms/step - loss: 51.5740 - val_loss: 55.8910
# Epoch 84/100
# 8/8 - 0s - 11ms/step - loss: 50.3546 - val_loss: 54.5988
# Epoch 85/100
# 8/8 - 0s - 11ms/step - loss: 49.1856 - val_loss: 53.3439
# Epoch 86/100
# 8/8 - 0s - 10ms/step - loss: 48.0310 - val_loss: 52.1248
# Epoch 87/100
# 8/8 - 0s - 11ms/step - loss: 46.9194 - val_loss: 50.9396
# Epoch 88/100
# 8/8 - 0s - 10ms/step - loss: 45.8267 - val_loss: 49.7935
# Epoch 89/100
# 8/8 - 0s - 11ms/step - loss: 44.7893 - val_loss: 48.6829
# Epoch 90/100
# 8/8 - 0s - 11ms/step - loss: 43.7750 - val_loss: 47.6064
# Epoch 91/100
# 8/8 - 0s - 10ms/step - loss: 42.8138 - val_loss: 46.5657
# Epoch 92/100
# 8/8 - 0s - 10ms/step - loss: 41.8677 - val_loss: 45.5511
# Epoch 93/100
# 8/8 - 0s - 12ms/step - loss: 40.9355 - val_loss: 44.5678
# Epoch 94/100
# 8/8 - 0s - 10ms/step - loss: 40.0435 - val_loss: 43.6147
# Epoch 95/100
# 8/8 - 0s - 11ms/step - loss: 39.1902 - val_loss: 42.6867
# Epoch 96/100
# 8/8 - 0s - 12ms/step - loss: 38.3511 - val_loss: 41.7864
# Epoch 97/100
# 8/8 - 0s - 11ms/step - loss: 37.5491 - val_loss: 40.9148
# Epoch 98/100
# 8/8 - 0s - 11ms/step - loss: 36.7662 - val_loss: 40.0717
# Epoch 99/100
# 8/8 - 0s - 10ms/step - loss: 36.0020 - val_loss: 39.2565
# Epoch 100/100
# 8/8 - 0s - 10ms/step - loss: 35.2767 - val_loss: 38.4614

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# linear_model = tf.keras.Sequential([
#     normalizer,
#     layers.Dense(units=1)
# ])
# linear_model.compile(
#     optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
#     loss='mean_squared_error')
#
# history = linear_model.fit(
#     train_features,
#     train_labels,
#     epochs=100,
#     # to view the logs, uncomment this:
#     verbose=0,
#     # validation split: 20% of the training data.
#     validation_split = 0.2)
#
# plot_loss(history)
# ```
#
# </details>

# %% [markdown]
# Predict the output values of the test set, and compute the RMSE.

# %%
y_pred = lr_model.predict(test_features)
print(np.sqrt(metrics.mean_squared_error(test_labels, y_pred)))
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 5.9247416408843225

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
#
# y_pred= linear_model.predict(test_features)
# print(np.sqrt(metrics.mean_squared_error(test_labels, y_pred)))
# ```
#
# </details>

# %% [markdown]
# ## Authors

# %% [markdown]
# [Kopal Garg](https://www.linkedin.com/in/gargkopal/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML311Coursera747-2022-01-01) is a Data Scientist Intern at IBM, and a Masters student in Computer Science at the University of Toronto.

# %% [markdown]
# ## Change Log

# %% [markdown]
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2022-07-06|0.1|Kopal|Create Lab||2022-08-09|0.2|Steve H.|QA pass|

# %% [markdown]
# Copyright © 2022 IBM Corporation. All rights reserved.

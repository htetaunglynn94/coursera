# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # Matrix Review
#
# Estimated time needed: **45** minutes

# %% [markdown]
# Matrix operations are a fundamental part of machine learning and many fields, such as digital signal processing, optimization, control systems, computer graphics, and so on. As a result, there has been a lot of work on optimizing matrix operations, not only in software, but in hardware. Let's say you work for a AI hardware  company, the company has developed a new processor that can only perform matrix operations. The company needs you to implement some popular  statistics such as mean, variance and Principle Component Analysis using Matrix operations

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/labs/module%203/images/technology-electronic-device-computer-hardware-computer-component-electronics-motherboard-personal-computer-hardware-cpu-computer-accessory-1536663.jpeg" width="500" alt="https://pxhere.com/en/photo/1536663">

# %% [markdown]
# ## Table of Contents
#
# <ol>
#     <li><a href="https://#Objectives">Objectives</a></li>
#     <li>
#         <a href="https://#Setup">Setup</a>
#         <ol>
#             <li><a href="https://#Installing-Required-Libraries">Installing Required Libraries</a></li>
#             <li><a href="https://#Importing-Required-Libraries">Importing Required Libraries</a></li>
#             <li><a href="https://#Defining-Helper-Functions">Defining Helper Functions</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="https://#Basics of Matrices">Basics of Matrices</a>
#         <ol>
#             <li><a href="https://https://https://#What's a Matrix?">What's a Matrix? </a></li>
#             <li><a href="https://https://https://#Rank of a Matrix">Rank of a Matrix </a></li>
#             <li><a href="https://#Frobenius Norm of a Matrix">Frobenius Norm of a Matrix</a></li>
#             <li><a href="https://#Matrix Additione"> Matrix Addition</a></li>
#         </ol>
#     </li>
#   <li>
#         <a href="https://https://#Matrix and Vector Multiplication">Matrix and Vector Multiplication</a>
#         <ol>
#             <li><a href="#What's a Matrix?"> Dot-Product </a></li>
#             <li><a href="#Rank of a Matrix">The Outer product</a></li>
#             <li><a href="#Matrix and Vector Multiplication">Matrix and Vector Multiplication</a></li>
#             <li><a href="https://#Matrix Multiplication">Multiplying Matrices</a></li>
#      </ol>
#    </li>
#    <li>
#         <a href="https://#Eigen Decomposition">Eigen Decomposition</a>
#         <ol>
#             <li><a href="#What's a Matrix?"> Eigenvectors and Eigenvalues </a></li>
#             <li><a href="#Rank of a Matrix">The Factorization for PCA</a></li>
#         </ol>
#    </li>
#
#  </ol>

# %% [markdown]
# ***

# %% [markdown]
# ## Objectives
#
# After completing this lab you will be able to:
#
# *   **Understand** Basic Matrix operations such as Matrix addition, Vector Multiplication  Eigen decomposition
#
# *   **Apply** Apply these Matrix operations using numpy

# %% [markdown]
# ## Setup

# %% [markdown]
# For this lab, we will be using the following libraries:
#
# *   [`pandas`](https://pandas.pydata.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML240ENSkillsNetwork34171862-2022-01-01) for managing the data.
# *   [`numpy`](https://numpy.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML240ENSkillsNetwork34171862-2022-01-01) for mathematical operations.
# *   [`seaborn`](https://seaborn.pydata.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML240ENSkillsNetwork34171862-2022-01-01) for visualizing the data.
# *   [`matplotlib`](https://matplotlib.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML240ENSkillsNetwork34171862-2022-01-01) for visualizing the data.
# *   [`sklearn`](https://scikit-learn.org/stable/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML240ENSkillsNetwork34171862-2022-01-01) for machine learning and machine-learning-pipeline related functions.

# %% [markdown]
# ### Installing required libraries

# %% [markdown]
# The following required modules are pre-installed in the Skills Network Labs environment. However, if you run this notebook commands in a different Jupyter environment (e.g. Watson Studio or Ananconda) you will need to install these libraries by removing the `#` sign before `!mamba` in the code cell below.

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented.
# !mamba install -qy pandas==1.3.4 numpy==1.21.4 seaborn==0.9.0 matplotlib==3.5.0 scikit-learn==0.20.1
# Note: If your environment doesn't support "!mamba install", use "!pip install pandas ==1.3.4 ..."

# %% [markdown]
# You can install and use  <a href="https://www.sympy.org/en/index.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2022-01-01">SymPy </a> to print matrices

# %%
# !conda install -c anaconda sympy -y
# Out:
# /bin/bash: line 1: conda: command not found

# %% [markdown]
# ### Importing required libraries

# %%
def warn(*args, **kwargs):
  pass

import warnings
warnings.warn = warn

# %%
import numpy as np
# Imports both pyplot and numpy functions into the same namespace
import matplotlib.pylab as plt

from sklearn.decomposition import PCA
# 'sympy' for symbolic mathematics (like algebra in math)
from sympy import Matrix             # symbolic matrix
from sympy import init_printing      # retty-printed output (LaTeX-style)
from sympy import Symbol             # symbolic variable

# 'numpy' linear algebra
from numpy.linalg import qr          # QR decomposition
from numpy.linalg import eig         # calculates eigenvalues and eigenvectors
from numpy.linalg import inv         # matrix inverse
from numpy.linalg import matrix_rank # rank of a matrix (number of linearly independent rows/columns)
from numpy.linalg import norm        # vector/matrix norms (length or magnitude)
from scipy.linalg import null_space  # null space (or kernel) of a matrix
init_printing()                      # enable pretty printing for matrix

# %% [markdown]
# ### Defining Helper Functions
#
# *Use this section to define any helper functions to help the notebook's code readability:*

# %%
def plot_2d(dict_):
    for key, value in dict_.items():
        if value.shape[0]>2:
            plt.scatter(value[:, 0], value[:, 1],label=key)
        else:
            print(value)
            plt.quiver([0],[0],value[:,0],value[:,1],label=key)

    plt.legend()
    plt.show()

# %% [markdown]
# ## Basics of Matrices

# %% [markdown]
# ### What's a Matrix

# %% [markdown]
# Numpy treats matrix objects as numpy arrays, so we will use Numpy to create matrices. Let's consider the square matrix A.

# %% [markdown]
# **NOTE**: We use the function `Matrix` to print out the Matrix , each column of matrix has two columns: Matrix $\mathbf{A}=[\mathbf{a}*{1},\mathbf{a}*{2}]$

# %%
A = plt.array([[2,-3], [4,7]])
Matrix(A)
# Out:
# ⎡2  -3⎤
# ⎢     ⎥
# ⎣4  7 ⎦

# %%
a1 = A[:, 0]
Matrix(a1)
# Out:
# ⎡2⎤
# ⎢ ⎥
# ⎣4⎦

# %%
a2 = A[:, 1]
Matrix(a2)
# Out:
# ⎡-3⎤
# ⎢  ⎥
# ⎣7 ⎦

# %% [markdown]
# Denoted by $A^{T}$, the transpose of a matrix  switches the row and column indices of the matrix, in numpy we can determine the transpose of $A$ as follows:

# %%
AT = A.T
Matrix(AT)
# Out:
# ⎡2   4⎤
# ⎢     ⎥
# ⎣-3  7⎦

# %% [markdown]
# ### Rank of a Matrix

# %% [markdown]
# The rank of a matrix is the number of dimension the rows of the matrix "live in".  You can verify the Matrix truly behaves like a  square matrix if it's <a href='https://en.wikipedia.org/wiki/Rank_(linear_algebra)?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2022-01-01'>rank</a> is equal to the number of rows or columns, then it is referred to as **full rank**.

# %%
matrix_rank(A)
# 2 linearly independent vectors in matrix A
# Out:
# np.int64(2)

# %% [markdown]
# We can plot the columns of $A$ as vectors.

# %%
A[0,0], A[0,1]
# Out:
# (np.int64(2), np.int64(-3))

# %%
plt.figure(figsize=(10,7))

plt.quiver([0,0],          # starting x-coordinates of arrows
           [0,0],          # starting y-coordinates of arrows
           2,              # x-components of the vector(s)
           3,              # y-components of the vector(s)
           color = 'r',        # color of the arrow
           scale = 30,         # arrow length
           label = "$a_{1}$")  # leegend

plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,7))

ax.quiver([0,0], [0,0], A[0,0], A[1,0], color='r', scale=30, label="$a_{1}$")
ax.quiver([0,0], [0,0], A[0,1], A[1,1], color='b', scale=30, label="$a_{2}$")
plt.title("Columns of $A$")
plt.legend()
plt.show()

# %% [markdown]
# As the vectors are not parallel, we can define any point on the 2d space as a scaled  combination of those two vectors.
#
# If any of the columns in a matrix  are multiples of each other, the vectors point in the same direction and the matrix is not full rank.

# %%
F = plt.array([[2,4], [4,8]])
matrix_rank(F)
# Out:
# np.int64(1)

# %% [markdown]
# We see the columns are pointing  in the same direction

# %%
fig, ax = plt.subplots(figsize= (12,7))
ax.quiver([0,0], [0, 0], F[0,1], F[1,1], scale=30, label="$f_{2}$",color='red')
ax.quiver([0,0], [0, 0], F[0,0], F[1,0], scale=30, label="$f_{1}$")
plt.title("Column of $F$")
plt.legend()
plt.show()

# %% [markdown]
# A common occurance is a matrix with more columns than rows, but in data, more rows than columns is more common. Consider the matrix $F$.

# %%
F = plt.array([[1,2], [1,-2], [-1,1]])
Matrix(F)
# Out:
# ⎡1   2 ⎤
# ⎢      ⎥
# ⎢1   -2⎥
# ⎢      ⎥
# ⎣-1  1 ⎦

# %% [markdown]
# Although, the rows of matrix $F$ are 3 dimensions, you can only describe the point lying in the 2D plane, as shown here:

# %%
F.T
# Out:
# array([[ 1,  1, -1],
#        [ 2, -2,  1]])

# %%
p = null_space(F.T)
Matrix(p)
# Out:
# ⎡0.196116135138184⎤
# ⎢                 ⎥
# ⎢0.588348405414552⎥
# ⎢                 ⎥
# ⎣0.784464540552736⎦

# %% [markdown]
# `null_space()` equation:
# $\begin{bmatrix}1 & 1 & -1 \\ 2 & -2 & 1 \end{bmatrix} \begin{bmatrix}x_1 \\ x_2 \\ x_3 \end{bmatrix} = \begin{bmatrix} 0 \\ 0 \end{bmatrix}$

# %%
xx, yy = plt.meshgrid(plt.arange(-3,3,0.1), plt.arange(-3,3,0.1))
xx.shape, yy.shape
# Out:
# ((60, 60), (60, 60))

# %%
z = (p[0] * xx + p[1] * yy) / p[2]

# %%
ax = plt.figure().add_subplot(projection='3d')
ax.plot_surface(xx, yy, z, alpha=0.3)
ax.quiver([0,0], [0,0], [0,0], F[0,:], F[1,:], F[2,:])

ax.set_xlim([-3, 3])
ax.set_ylim([-3, 3])
ax.set_zlim([-3, 3])
plt.show()

# %% [markdown]
# Therefore, the rank is 2.

# %%
matrix_rank(F)
# Out:
# np.int64(2)

# %% [markdown]
# ### Frobenius Norm of a Matrix

# %% [markdown]
# The Frobenius norm, sometimes also called the **Euclidean norm**, is the matrix norm of an $m×n$. Matrix A is defined as the square root of the sum of the absolute squares of its elements:
#
# $$|A| *F = \sqrt{\sum*{i=1}^m \sum\_{j=1}^n |a\_{ij}|^2}$$
#
# Let's use the matrix A again as an example:

# %%
Matrix(A), norm(A)
# Out:
# ⎛⎡2  -3⎤                   ⎞
# ⎜⎢     ⎥, 8.831760866327848⎟
# ⎝⎣4  7 ⎦                   ⎠

# %% [markdown]
# You could also calculate the matrix norm manually, using the formula provided above, and confirm that the results are the same.

# %%
m, n = A.shape[0], A.shape[1] # number of rows and columns
m, n
# Out:
# (2, 2)

# %%
ss = 0

for i in range(m):
  for j in range(n):
    ss += A[i,j] ** 2
plt.sqrt(ss)
# Out:
# np.float64(8.831760866327848)

# %% [markdown]
# ### Matrix Addition

# %% [markdown]
# Consider matrix $B$:

# %%
B = plt.array([[1,1], [1,-1]])
Matrix(B)
# Out:
# ⎡1  1 ⎤
# ⎢     ⎥
# ⎣1  -1⎦

# %% [markdown]
# In general, if we have matrix $\mathbf{A}$ and matrix $\mathbf{B}$

# %% [markdown]
# $\begin{align}
# \mathbf{A}= \begin{bmatrix}
# a\_{11} & a\_{12} & \cdots & a\_{1n} \\\\\\
# a\_{21} & a\_{22} & \cdots & a\_{2n} \\\\\\
# \vdots & \vdots & \ddots & \vdots \\\\\\
# a\_{m1} & a\_{m2} & \cdots & a\_{mn} \\\\\\
# \end{bmatrix}
# \end{align}$
# $\begin{align}
# \mathbf{B}=\begin{bmatrix}
# b\_{11} & b\_{12} & \cdots & b\_{1n} \\\\\\
# b\_{21} & b\_{22} & \cdots & b\_{2n} \\\\\\
# \vdots & \vdots & \ddots & \vdots \\\\\\
# b\_{m1} & b\_{m2} & \cdots & b\_{mn} \\\\\\
# \end{bmatrix}
# \end{align}$

# %% [markdown]
# To be added, the two matrices must have an equal number of rows and columns, where we add the corresponding row and column element:

# %% [markdown]
# $\begin{align}
# \mathbf{A}+\mathbf{B}=\begin{bmatrix}
# a\_{11} + b\_{11} & a\_{12} + b\_{12} & \cdots & a\_{1n} + b\_{1n} \\\\\\
# a\_{21} + b\_{21} & a\_{22} + b\_{22} & \cdots & a\_{2n} + b\_{2n} \\\\\\
# \vdots & \vdots & \ddots & \vdots \\\\\\
# a\_{m1} + b\_{m1} & a\_{m2} + b\_{m2} & \cdots & a\_{mn} + b\_{mn} \\\\\\
# \end{bmatrix}
# \end{align}$

# %% [markdown]
# In numpy, we can add two arrays as follows:

# %%
C = A + B
Matrix(C)
# Out:
# ⎡3  -2⎤
# ⎢     ⎥
# ⎣5  6 ⎦

# %% [markdown]
# This matrix is symmetric. This means $B=B^{T}$, we can verify this in Python:

# %%
B_T = B.T
Matrix(B_T)
# Out:
# ⎡1  1 ⎤
# ⎢     ⎥
# ⎣1  -1⎦

# %% [markdown]
# Arbitrary semantic matrix $S=C+C^T$, where $C$ is any matrix.

# %%
C = np.random.randn(2, 2)
S = C + C.T
Matrix(S)
# Out:
# ⎡-2.73472494394066  -1.00326298584394⎤
# ⎢                                    ⎥
# ⎣-1.00326298584394  -1.2328083280237 ⎦

# %%
Matrix(S.T)
# Out:
# ⎡-2.73472494394066  -1.00326298584394⎤
# ⎢                                    ⎥
# ⎣-1.00326298584394  -1.2328083280237 ⎦

# %% [markdown]
# <b>Diagonal matrix</b> is a matrix in which the entries outside of the main diagonal are all zero.

# %%
Matrix(np.diag(np.array([1,2,3])))
# Out:
# ⎡1  0  0⎤
# ⎢       ⎥
# ⎢0  2  0⎥
# ⎢       ⎥
# ⎣0  0  3⎦

# %% [markdown]
# If the main diagonal is one, it's called a identity matrix in numpy.

# %%
Matrix(np.eye(3).astype(int)) # 3 x 3 matrix
# Out:
# ⎡1  0  0⎤
# ⎢       ⎥
# ⎢0  1  0⎥
# ⎢       ⎥
# ⎣0  0  1⎦

# %% [markdown]
# ## Matrix and Vector Multiplication

# %% [markdown]
# ### Dot-Product

# %% [markdown]
# We can define a vector as a one dimensional array of $\mathbf{a}$ and $\mathbf{b}$, and we can find the dot product of the two as follows:

# %% [markdown]
# $ a^T  b = \sum\_{i=1}^n a_i b_i = a\_1 b\_1 + \cdots + a_n b_n$

# %% [markdown]
# Where  $\mathbf{a}$ and  $\mathbf{b}$ have the same length, in numpy:

# %%
a = np.array([1,1])
b = np.array([1,2])

# %% [markdown]
# We can verify that the dimension is one.

# %%
a.ndim, b.ndim
# Out:
# (1, 1)

# %% [markdown]
# Find the dot product

# %%
# dot product
a @ b
# Out:
# np.int64(3)

# %% [markdown]
# If the array is 2- dimension, the order matters. $a^{T}$ must be a row vector of shape $1xm$ and $b$ a column vector of shape $mx1$.

# %% [markdown]
# $a^{T} = \begin{bmatrix}
# a\_{1},a\_{2},..,a\_{n}
# \end{bmatrix}$
#
# $b = \begin{bmatrix}
# b\_{1} \\\\\\
# b\_{2} \\\\\\
# \vdots \\\\\\
# b\_{n}
# \end{bmatrix}$

# %%
a = np.array([[1], [1]])
b = np.array([[1], [2]])
Matrix(a)
# Out:
# ⎡1⎤
# ⎢ ⎥
# ⎣1⎦

# %%
a.T @ b # dot product after transpose
# Out:
# array([[3]])

# %% [markdown]
# ### Exercise 1
#
# Calculate the dot product of $a$ and $one$.

# %%
one = np.ones(2)
one
# Out:
# array([1., 1.])

# %%
a.T @ one
# Out:
# array([2.])

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# a.T@one
# ```
#
# </details>

# %% [markdown]
# ### The Outer product

# %% [markdown]
# The outer product is another useful matrix operation. Consider the matrix or vector $ \mathbf{u}$ of size $nx1$ and matrix or vector $\mathbf{v}$ $1xm$. Then their outer product is:

# %% [markdown]
# $
# \mathbf{u} \otimes \mathbf{v} = \mathbf{u}\mathbf{v}^\textsf{T} =
# \begin{bmatrix}u\_1 \\\\\ u\_2 \ \vdots\ u_n\end{bmatrix}
# \begin{bmatrix}v\_1 & .. & v_m\end{bmatrix} =
# \begin{bmatrix}
# u\_1 v\_1 & .. & u\_1 v_m\\\\\\
# u\_2 v\_1 & u\_2 v\_2 & u\_2 v\_3 \\\\\\
# \vdots   & \ddots & \vdots \\\\\\
# u_n v\_1 &  .. & u_n v_m
# \end{bmatrix}.
# $

# %% [markdown]
# We can perform the outer product in numpy as follows

# %%
u= np.array([[1],[2],[3],[4]])
v= np.array([[0],[1],[2],[3],[6]])

Matrix(u @ v.T)
# Out:
# ⎡0  1  2  3   6 ⎤
# ⎢               ⎥
# ⎢0  2  4  6   12⎥
# ⎢               ⎥
# ⎢0  3  6  9   18⎥
# ⎢               ⎥
# ⎣0  4  8  12  24⎦

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# Matrix(u@v.T)
# ```
#
# </details>

# %% [markdown]
# ### Exercise 2
#
# Create a matrix with 4 columns where each even column is  the vector  `u`  or else it is  zero, show the rank is one:

# %%
u = np.array([[1],[2]])
Matrix(u)
# Out:
# ⎡1⎤
# ⎢ ⎥
# ⎣2⎦

# %%
Matrix(u @ np.array([[0,1,0,1]]))
# Out:
# ⎡0  1  0  1⎤
# ⎢          ⎥
# ⎣0  2  0  2⎦

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# Matrix(u@np.array([[0,1,0,1]]))
# ```
#
# </details>

# %% [markdown]
# ### Matrix and Vector Multiplication

# %% [markdown]
# We can also multiply a matrix by a vector and get a new vector. Consider the vector $\mathbf{x}$:

# %% [markdown]
# $
# \mathbf{x}=
# \begin{bmatrix}
# x\_1 \\\\\\
# x\_2 \\\\\\
# \vdots \\\\\\
# x_n
# \end{bmatrix}
# $

# %% [markdown]
# The following  $\mathbf{Ax}=\mathbf b$  matrix multiplication  is defined as the dot product  $\mathbf{x}$ with each row of $\mathbf{A}$ :

# %% [markdown]
# $
# \begin{matrix}a\_{11}x\_1+\cdots + a\_{1n}x_n=b\_1
# \\\\\ a\_{21}x\_1+\cdots + a\_{2n}x_n =b\_2
# \\\\\ \vdots
# \\\\\ a\_{m1}x\_1+\cdots + a\_{mn}x_n =b_m\end{matrix}
# $

# %% [markdown]
# Where ,

# %% [markdown]
# $
# \mathbf{b}=
# \begin{bmatrix}
# b\_1 \\\\\\
# b\_2 \\\\\\
# \vdots \\\\\\
# b_m
# \end{bmatrix}
# $

# %% [markdown]
# In numpy:

# %%
Matrix(np.array([[1,1]]))  # with double brackets
# Out:
# [1  1]

# %%
x = np.array([1,1])   # with single brackets
Matrix(x)
# Out:
# ⎡1⎤
# ⎢ ⎥
# ⎣1⎦

# %%
A = np.array([[-1,1], [1,2]])
Matrix(A)
# Out:
# ⎡-1  1⎤
# ⎢     ⎥
# ⎣1   2⎦

# %%
# equation: Ax = b
b = A @ x
Matrix(b)
# Out:
# ⎡0⎤
# ⎢ ⎥
# ⎣3⎦

# %% [markdown]
# We can see that $b$ is a combination of the rows of $A$:
#
# $\mathbf{b}=x\_{1}\mathbf{a}*{1}+\mathbf{x}*{2}a\_{2}$ or $\mathbf{b}$ is a rotation of  $\mathbf{x}$

# %%
fig, ax = plt.subplots(figsize=(12,7))
ax.quiver([0,0], [0,0], A[0,0], A[1,0], scale=10, label="$a_{1}$")
ax.quiver([0,0], [0,0], A[0,1], A[1,1], scale=10, label="$a_{2}$")
ax.quiver([0,0], [0,0], b[0], b[1], scale=10, label='b', color='r')
ax.quiver([0,0], [0,0], x[0], x[1], scale=10, label='x', color='b')
ax.set_xlim([-10, 10])
ax.set_ylim([-5, 10])
fig.legend()
plt.show()

# %% [markdown]
# ### Multiplying Matrices

# %% [markdown]
# If a matrix $\mathbf{C}$ is the product of matrix $\mathbf{A}$ and matrix $\mathbf{B}$, then the $i-th$ row $j-th$ column is obtained by multiplying term-by-term the entries of the $i-th$ row of $\mathbf{A}$ and the $j-th$ column of $\mathbf{B}$, and summing these $n$ products. In other words, you can also think of the  $i-th$ row $j-th$ column as the dot product of the $i-th$ row of $\mathbf{A}$  and the $j-th$ column of $\mathbf{B}$:

# %% [markdown]
# $\mathbf{C}=\mathbf{AB}$
#
# $=\begin{pmatrix}
# a\_{11}b\_{11} +\cdots + a\_{1n}b\_{n1} & a\_{11}b\_{12} +\cdots + a\_{1n}b\_{n2} & \cdots & a\_{11}b\_{1p} +\cdots + a\_{1n}b\_{np} \\\\\\
# a\_{21}b\_{11} +\cdots + a\_{2n}b\_{n1} & a\_{21}b\_{12} +\cdots + a\_{2n}b\_{n2} & \cdots & a\_{21}b\_{1p} +\cdots + a\_{2n}b\_{np} \\\\\\
# \vdots & \vdots & \ddots & \vdots \\\\\\
# a\_{m1}b\_{11} +\cdots + a\_{mn}b\_{n1} & a\_{m1}b\_{12} +\cdots + a\_{mn}b\_{n2} & \cdots & a\_{m1}b\_{1p} +\cdots + a\_{mn}b\_{np} \\\\\\
# \end{pmatrix} $

# %%
Matrix(A), Matrix(B)
# Out:
# ⎛⎡-1  1⎤  ⎡1  1 ⎤⎞
# ⎜⎢     ⎥, ⎢     ⎥⎟
# ⎝⎣1   2⎦  ⎣1  -1⎦⎠

# %%
C = A @ B
Matrix(C)
# Out:
# ⎡0  -2⎤
# ⎢     ⎥
# ⎣3  -1⎦

# %% [markdown]
# You can repeat the process for more matrices, if the matrix is full rank, we can invert it: $\mathbf{A}^{-1}$

# %%
A_inv = inv(A)
Matrix(A_inv)
# Out:
# ⎡-0.666666666666667  0.333333333333333⎤
# ⎢                                     ⎥
# ⎣0.333333333333333   0.333333333333333⎦

# %% [markdown]
# This can be a complex computation. If we multiply a matrix with its inverse, we get the Identity matrix $\mathbf{AA}^{-1}=I$.

# %%
I = A_inv @ A
Matrix(I)
# Out:
# ⎡1.0  -1.11022302462516e-16⎤
# ⎢                          ⎥
# ⎣0.0           1.0         ⎦

# %% [markdown]
# If we multiply any square matrix with an Identity matrix, we get the original Matrix, for example $IA=A$ in numpy:

# %%
Matrix(A @ I)
# Out:
# ⎡-1.0  1.0⎤
# ⎢         ⎥
# ⎣1.0   2.0⎦

# %% [markdown]
# ### Exercise 3
#
# Use the inverse of  matrix $\mathbf{A}$ to solve for $\mathbf{x}$ given $\mathbf{b}$ and assign it to `x_` compare the result to `x`
#
# $Ax = b$ --> $x = A^{-1}b$

# %%
# Find value of x given by the b values --> Ax = b --> x = A
x_ = A_inv @ b
display("x_:", x_)
display("x:", x)
# Out:
# 'x_:'
# array([1., 1.])
# 'x:'
# array([1, 1])

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# x_=A_inv@b
# print("x_ :",x_)
# print("x:",x)
# ```
#
# </details>

# %% [markdown]
# Another type of matrixes is the **orthogonal matrix**. An <b>orthogonal matrix</b> is extremely useful: if matrix $Q$ is orthogonal, such as $Q^T=Q^{-1}$, the rows and columns are orthogonal also. For example:

# %%
# Transposed Matrix = Inversed Matrix
Q = np.array([[1,1], [1,-1]])*2**(-1/2)
Matrix(Q)
# Out:
# ⎡0.707106781186548  0.707106781186548 ⎤
# ⎢                                     ⎥
# ⎣0.707106781186548  -0.707106781186548⎦

# %% [markdown]
# We can verify that $Q^T=Q^{-1}$:

# %%
Matrix(Q.T), Matrix(inv(Q))
# Out:
# ⎛⎡0.707106781186548  0.707106781186548 ⎤  ⎡0.707106781186547  0.70710678118654 ↪
# ⎜⎢                                     ⎥, ⎢                                    ↪
# ⎝⎣0.707106781186548  -0.707106781186548⎦  ⎣0.707106781186547  -0.7071067811865 ↪
#
# ↪ 7 ⎤⎞
# ↪   ⎥⎟
# ↪ 47⎦⎠

# %%
# Identity matrix
I = Q @ Q.T
Matrix(I)
# Out:
# ⎡        1.0           4.26642158858964e-17⎤
# ⎢                                          ⎥
# ⎣4.26642158858964e-17          1.0         ⎦

# %% [markdown]
# For an <b>orthogonal matrix</b>, the columns are orthogonal:

# %%
fig, ax = plt.subplots(figsize = (12, 7))
ax.quiver([0,0], [0,0], B[0,0], B[1,0], scale=10, label="$q_{1}$")
ax.quiver([0,0], [0,0], B[0,1], B[1,1], scale=10, label="$q_{2}$")
plt.title("columns of $B$ ")
plt.legend()
plt.show()

# %% [markdown]
# We usually place our data in a design matrix $X$, which is a matrix where each row represents an individual sample. Consider the following example `X_`

# %%
u = np.array([[1.0,1.0], [0.10,-0.10]])/(2) ** (0.5)
Matrix(u)
# Out:
# ⎡0.707106781186547    0.707106781186547 ⎤
# ⎢                                       ⎥
# ⎣0.0707106781186548  -0.0707106781186548⎦

# %%
samples = 200

# %%
X_ = np.dot(4 * np.random.randn(samples, 2), u) * 10
Matrix(X_[0:5])
# Out:
# ⎡6.34693083850809   2.73697706625884⎤
# ⎢                                   ⎥
# ⎢-69.2038948841955  -64.115396842135⎥
# ⎢                                   ⎥
# ⎢8.77762245324245   11.1058519713502⎥
# ⎢                                   ⎥
# ⎢19.5359573948518   15.7871678867877⎥
# ⎢                                   ⎥
# ⎣36.9962756015892   28.3142942842415⎦

# %% [markdown]
# We can plot the samples:

# %%
def plot_2d(dict_):
    for key, value in dict_.items(): # separate 'key' and 'value'
        if value.shape[0] > 2: # if number of values > 2
            plt.scatter(value[:,0], value[:,1], label=key) # scatter plot for values
        else:
            print(value) # print values
            plt.quiver([0], [0], value[:,0], value[:,1], label=key) # vector plot

    plt.legend() # show legend
    plt.show() # show plot

# %%
dict_ = {"design matrix samples":X_}
plot_2d(dict_)

# %% [markdown]
# We can find the shape of the design matrix:

# %%
N, D = X_.shape
print("number of smaples {}, dimensions is {}".format(N,D))
# Out:
# number of smaples 200, dimensions is 2

# %% [markdown]
# We can also perform lots of operations with Matrix multiplication, for example we can calculate the mean with the following:

# %%
Matrix((np.ones((1,N))/N))  # (1 x 200)
# Out:
# [0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005   ↪
#
# ↪ 0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  ↪
#
# ↪  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005 ↪
#
# ↪   0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.00 ↪
#
# ↪ 5  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.0 ↪
#
# ↪ 05  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0. ↪
#
# ↪ 005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0 ↪
#
# ↪ .005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005   ↪
#
# ↪ 0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  ↪
#
# ↪  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005 ↪
#
# ↪   0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.00 ↪
#
# ↪ 5  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.0 ↪
#
# ↪ 05  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0. ↪
#
# ↪ 005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0 ↪
#
# ↪ .005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005   ↪
#
# ↪ 0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  ↪
#
# ↪  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005 ↪
#
# ↪   0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.005  0.00 ↪
#
# ↪ 5  0.005  0.005  0.005  0.005]

# %%
Matrix(X_)
# Out:
# ⎡ 6.34693083850809    2.73697706625884 ⎤
# ⎢                                      ⎥
# ⎢-69.2038948841955    -64.115396842135 ⎥
# ⎢                                      ⎥
# ⎢ 8.77762245324245    11.1058519713502 ⎥
# ⎢                                      ⎥
# ⎢ 19.5359573948518    15.7871678867877 ⎥
# ⎢                                      ⎥
# ⎢ 36.9962756015892    28.3142942842415 ⎥
# ⎢                                      ⎥
# ⎢-33.5175742998459   -35.5813190021199 ⎥
# ⎢                                      ⎥
# ⎢-15.2276451872596   -23.9041094313682 ⎥
# ⎢                                      ⎥
# ⎢-34.1678191210358   -30.3209701819081 ⎥
# ⎢                                      ⎥
# ⎢0.812679992400351    1.4692456026716  ⎥
# ⎢                                      ⎥
# ⎢ 21.1753275144225    21.5525961563918 ⎥
# ⎢                                      ⎥
# ⎢-12.0964911890313   -13.2598465134958 ⎥
# ⎢                                      ⎥
# ⎢ 59.6051199578775    45.4860815619185 ⎥
# ⎢                                      ⎥
# ⎢-41.2236586425542   -45.8676938429015 ⎥
# ⎢                                      ⎥
# ⎢ 6.34048788548267    11.4156056030692 ⎥
# ⎢                                      ⎥
# ⎢-17.5277619930729   -21.0391663967968 ⎥
# ⎢                                      ⎥
# ⎢ 7.80935251754356    2.1225528818477  ⎥
# ⎢                                      ⎥
# ⎢-46.1982190148716   -46.4978014682289 ⎥
# ⎢                                      ⎥
# ⎢-16.7728690973935   -17.5819926571217 ⎥
# ⎢                                      ⎥
# ⎢ 19.0518907115828    15.9594383325331 ⎥
# ⎢                                      ⎥
# ⎢ 15.3715490156723    19.9753949983282 ⎥
# ⎢                                      ⎥
# ⎢ 20.029621991934     26.1183477039828 ⎥
# ⎢                                      ⎥
# ⎢ 3.15582166787437    2.58743943456133 ⎥
# ⎢                                      ⎥
# ⎢ 69.5769831436135    72.7007546564864 ⎥
# ⎢                                      ⎥
# ⎢ 1.42816364892196   -0.631788713970513⎥
# ⎢                                      ⎥
# ⎢-53.3133619129727   -45.5516588731185 ⎥
# ⎢                                      ⎥
# ⎢ 28.7388737336202    42.0847184022877 ⎥
# ⎢                                      ⎥
# ⎢-8.77686083363349   -1.09923399830739 ⎥
# ⎢                                      ⎥
# ⎢ 9.47801408829289    9.04127686436772 ⎥
# ⎢                                      ⎥
# ⎢ 51.9379980583262    47.9157432955124 ⎥
# ⎢                                      ⎥
# ⎢ 12.7120270751405    11.647783653636  ⎥
# ⎢                                      ⎥
# ⎢0.218766921206156   0.685596210296708 ⎥
# ⎢                                      ⎥
# ⎢-72.1082348782542   -58.3968450025225 ⎥
# ⎢                                      ⎥
# ⎢ -10.216920205081   -14.9970823529542 ⎥
# ⎢                                      ⎥
# ⎢ 49.2802860207601    43.3156411249119 ⎥
# ⎢                                      ⎥
# ⎢-31.7536444499613   -25.8986010745301 ⎥
# ⎢                                      ⎥
# ⎢ 24.5779888033343    24.5587605961096 ⎥
# ⎢                                      ⎥
# ⎢ 10.7310334760649    4.34468160843068 ⎥
# ⎢                                      ⎥
# ⎢ 31.5385716079099    26.6652139970159 ⎥
# ⎢                                      ⎥
# ⎢-6.37850120126274   -6.10914056932592 ⎥
# ⎢                                      ⎥
# ⎢ 40.4210251758424    31.7196353858522 ⎥
# ⎢                                      ⎥
# ⎢ 45.0330098132441    38.4767294047988 ⎥
# ⎢                                      ⎥
# ⎢ -43.755744874332   -37.3606822167828 ⎥
# ⎢                                      ⎥
# ⎢ 32.7202650491357    31.0877727530048 ⎥
# ⎢                                      ⎥
# ⎢ 8.90938904162489    7.56660261806522 ⎥
# ⎢                                      ⎥
# ⎢-49.7667255970631   -41.5325026357923 ⎥
# ⎢                                      ⎥
# ⎢-2.65236851649904    2.17310552801191 ⎥
# ⎢                                      ⎥
# ⎢ 11.5255397552528    13.422125285714  ⎥
# ⎢                                      ⎥
# ⎢ 26.9842588848284    24.0232384742467 ⎥
# ⎢                                      ⎥
# ⎢ 10.9149442253126    18.4868612088724 ⎥
# ⎢                                      ⎥
# ⎢ 4.44983501710027    4.40002590288209 ⎥
# ⎢                                      ⎥
# ⎢-17.9063052169955   -18.5229593015146 ⎥
# ⎢                                      ⎥
# ⎢ -2.886533313652    -7.09567921170868 ⎥
# ⎢                                      ⎥
# ⎢-36.7475361040199   -28.5739924181478 ⎥
# ⎢                                      ⎥
# ⎢ 8.72694456157839    2.04127075090691 ⎥
# ⎢                                      ⎥
# ⎢ 66.2888833247044    69.3440713400236 ⎥
# ⎢                                      ⎥
# ⎢-33.6036461190731   -38.1334265047065 ⎥
# ⎢                                      ⎥
# ⎢-13.6740899920521   -9.43747378932994 ⎥
# ⎢                                      ⎥
# ⎢ 33.2090689018764    22.6051177684429 ⎥
# ⎢                                      ⎥
# ⎢ 46.2136953692156    45.9567577462801 ⎥
# ⎢                                      ⎥
# ⎢-29.1635992632992   -37.3311503403928 ⎥
# ⎢                                      ⎥
# ⎢ -29.913897464223   -31.0009280742445 ⎥
# ⎢                                      ⎥
# ⎢-42.3675772225786   -39.3770238863732 ⎥
# ⎢                                      ⎥
# ⎢-7.85771942520944   -11.8033585193352 ⎥
# ⎢                                      ⎥
# ⎢-5.89810484361869   -4.67521515724897 ⎥
# ⎢                                      ⎥
# ⎢-0.232621416830246  -0.890084413157286⎥
# ⎢                                      ⎥
# ⎢ 57.8744847598174    61.343160954141  ⎥
# ⎢                                      ⎥
# ⎢ 40.8762399529466    55.1688744682925 ⎥
# ⎢                                      ⎥
# ⎢ 18.5995072228013    23.6634539081316 ⎥
# ⎢                                      ⎥
# ⎢-1.51243510192783   0.431189207060881 ⎥
# ⎢                                      ⎥
# ⎢-9.22871780972722   -15.0397236545128 ⎥
# ⎢                                      ⎥
# ⎢-12.0289454355601   -4.61226699547642 ⎥
# ⎢                                      ⎥
# ⎢-18.7251119446897   -20.2980789655377 ⎥
# ⎢                                      ⎥
# ⎢-61.4179565594259   -56.4565982419169 ⎥
# ⎢                                      ⎥
# ⎢ -9.3696050999078   -6.68836819335234 ⎥
# ⎢                                      ⎥
# ⎢ 11.6252047359112    20.5050991903908 ⎥
# ⎢                                      ⎥
# ⎢-11.3922292191389   -19.0755991005821 ⎥
# ⎢                                      ⎥
# ⎢-25.5411650507052   -24.4158154094765 ⎥
# ⎢                                      ⎥
# ⎢ -38.600160224361   -40.0321667080236 ⎥
# ⎢                                      ⎥
# ⎢ 7.63816181488847   -0.437499246810473⎥
# ⎢                                      ⎥
# ⎢-14.3177433138804   -10.6458991285092 ⎥
# ⎢                                      ⎥
# ⎢ 40.3733881994328    35.7213734887829 ⎥
# ⎢                                      ⎥
# ⎢-36.0158485807963   -42.1543745505429 ⎥
# ⎢                                      ⎥
# ⎢ 4.07131502380051    5.11353473591135 ⎥
# ⎢                                      ⎥
# ⎢ 25.9465283690673    26.952238410147  ⎥
# ⎢                                      ⎥
# ⎢ 32.947455573442     39.8038273047506 ⎥
# ⎢                                      ⎥
# ⎢ 48.9834433357421    50.6666992096776 ⎥
# ⎢                                      ⎥
# ⎢-42.7569649871846   -39.3529712745291 ⎥
# ⎢                                      ⎥
# ⎢-26.5337607951023   -25.5346616691867 ⎥
# ⎢                                      ⎥
# ⎢ 17.8620558668956    23.2821587973499 ⎥
# ⎢                                      ⎥
# ⎢ 25.8325338963878    37.8939868278014 ⎥
# ⎢                                      ⎥
# ⎢ 3.19661681893329   -4.63879084805923 ⎥
# ⎢                                      ⎥
# ⎢-41.5559084993893   -37.1152553677726 ⎥
# ⎢                                      ⎥
# ⎢ 20.1486297800384    10.7531218397412 ⎥
# ⎢                                      ⎥
# ⎢-1.27877662667609    3.58491112208053 ⎥
# ⎢                                      ⎥
# ⎢ 66.181087330773     64.9744937994135 ⎥
# ⎢                                      ⎥
# ⎢-8.59968048826015    6.69860734668173 ⎥
# ⎢                                      ⎥
# ⎢-0.18320709975868    0.45701310997289 ⎥
# ⎢                                      ⎥
# ⎢-14.6915992375476   -17.5182734010667 ⎥
# ⎢                                      ⎥
# ⎢-2.80126194356379   -13.1760059231189 ⎥
# ⎢                                      ⎥
# ⎢-26.6691973031114   -30.0254953149458 ⎥
# ⎢                                      ⎥
# ⎢ -7.4479977573981   -6.99886521585452 ⎥
# ⎢                                      ⎥
# ⎢ 95.0489399955839    102.099018568071 ⎥
# ⎢                                      ⎥
# ⎢-17.7702219824739   -18.2034334518279 ⎥
# ⎢                                      ⎥
# ⎢-13.3849982077667   -14.4649803378279 ⎥
# ⎢                                      ⎥
# ⎢-5.25400912039413   -11.5954830258179 ⎥
# ⎢                                      ⎥
# ⎢-7.00751557231742   -0.370448032562617⎥
# ⎢                                      ⎥
# ⎢ -34.627163393985   -36.9894112660008 ⎥
# ⎢                                      ⎥
# ⎢-19.4090082566321   -13.0949939784247 ⎥
# ⎢                                      ⎥
# ⎢ 2.93731663797358    3.01209217023867 ⎥
# ⎢                                      ⎥
# ⎢ -2.212719011054    -7.74619898560518 ⎥
# ⎢                                      ⎥
# ⎢ 56.6109594911264    49.6116427072363 ⎥
# ⎢                                      ⎥
# ⎢-5.46287360132908   -4.29158351153271 ⎥
# ⎢                                      ⎥
# ⎢ 12.5836446852529    16.0199349523874 ⎥
# ⎢                                      ⎥
# ⎢ 3.25436521649479    2.36328504047695 ⎥
# ⎢                                      ⎥
# ⎢0.096912952760573   -2.78951438164381 ⎥
# ⎢                                      ⎥
# ⎢ 9.44002254770289    8.53922807540294 ⎥
# ⎢                                      ⎥
# ⎢ 3.96645970915518    1.20497770137934 ⎥
# ⎢                                      ⎥
# ⎢-9.79309879013543   -10.1495202764669 ⎥
# ⎢                                      ⎥
# ⎢-4.73948684200703    2.29728035299639 ⎥
# ⎢                                      ⎥
# ⎢ 4.83723544453078    6.12901009158622 ⎥
# ⎢                                      ⎥
# ⎢ 8.81787234748299    14.9133893682399 ⎥
# ⎢                                      ⎥
# ⎢-48.4770066148895   -51.4176262759777 ⎥
# ⎢                                      ⎥
# ⎢-22.8529920833973   -22.5292531567449 ⎥
# ⎢                                      ⎥
# ⎢ 28.4059263199568    31.6562800990186 ⎥
# ⎢                                      ⎥
# ⎢ 60.2824222490578    54.5181046296868 ⎥
# ⎢                                      ⎥
# ⎢ 19.7597520257503    19.690372122755  ⎥
# ⎢                                      ⎥
# ⎢ 3.74238677249156    2.12479603081731 ⎥
# ⎢                                      ⎥
# ⎢-7.05842817964749   -18.8866066850531 ⎥
# ⎢                                      ⎥
# ⎢-16.5731512101786   -15.4678238711851 ⎥
# ⎢                                      ⎥
# ⎢-16.5664954662742   -15.3642863940185 ⎥
# ⎢                                      ⎥
# ⎢-6.39469344477387    7.14166108590109 ⎥
# ⎢                                      ⎥
# ⎢ 14.9663867769891    13.5767792036478 ⎥
# ⎢                                      ⎥
# ⎢-1.07590539124714    9.1001217206555  ⎥
# ⎢                                      ⎥
# ⎢-14.2481054166624   -11.8103531671813 ⎥
# ⎢                                      ⎥
# ⎢ 23.5119223200625    34.7685299654784 ⎥
# ⎢                                      ⎥
# ⎢ 11.0944167664957    2.51570157316975 ⎥
# ⎢                                      ⎥
# ⎢ 22.2252707618847    9.27138698426365 ⎥
# ⎢                                      ⎥
# ⎢ 35.2185791256492    41.2217563729784 ⎥
# ⎢                                      ⎥
# ⎢-3.95012872016481   -1.78783824523666 ⎥
# ⎢                                      ⎥
# ⎢-53.7142835320076   -46.6176972088085 ⎥
# ⎢                                      ⎥
# ⎢ 36.7679457139399    32.3177670820619 ⎥
# ⎢                                      ⎥
# ⎢-18.9973631709649   -20.8140963553545 ⎥
# ⎢                                      ⎥
# ⎢-8.03100790053377   -19.7505433914548 ⎥
# ⎢                                      ⎥
# ⎢-15.6012857372918   -14.5824033564568 ⎥
# ⎢                                      ⎥
# ⎢-6.45275191176225   -3.67930184544819 ⎥
# ⎢                                      ⎥
# ⎢ 10.8089376373665    10.6579777979703 ⎥
# ⎢                                      ⎥
# ⎢-13.4858302668904   -5.11515542012616 ⎥
# ⎢                                      ⎥
# ⎢ 2.79193941971089   0.955964210831414 ⎥
# ⎢                                      ⎥
# ⎢ 46.5863722358207    39.9896948337067 ⎥
# ⎢                                      ⎥
# ⎢-31.4722881864246    -31.872368579962 ⎥
# ⎢                                      ⎥
# ⎢ 10.900683870539     13.6993240126091 ⎥
# ⎢                                      ⎥
# ⎢ 22.4930215043618    23.3426589780665 ⎥
# ⎢                                      ⎥
# ⎢-58.8302540925066   -54.8144436246749 ⎥
# ⎢                                      ⎥
# ⎢-2.63533311611061    4.43859369028441 ⎥
# ⎢                                      ⎥
# ⎢ 10.1106152146304    9.2073415584756  ⎥
# ⎢                                      ⎥
# ⎢  -55.2599534712    -47.9429365003785 ⎥
# ⎢                                      ⎥
# ⎢ 9.38228422966625    9.06786307778772 ⎥
# ⎢                                      ⎥
# ⎢-21.5577671493301   -27.3721358042034 ⎥
# ⎢                                      ⎥
# ⎢ 23.4513802549012    19.9466501400231 ⎥
# ⎢                                      ⎥
# ⎢-25.2063269861586   -18.0818766907296 ⎥
# ⎢                                      ⎥
# ⎢-21.8752857796722   -36.3131502042498 ⎥
# ⎢                                      ⎥
# ⎢ 5.42513910344657    11.3855625666196 ⎥
# ⎢                                      ⎥
# ⎢ 20.8362385406726    14.8578611614731 ⎥
# ⎢                                      ⎥
# ⎢ 2.25796118372381    13.7487623506669 ⎥
# ⎢                                      ⎥
# ⎢ 18.5571359455283    17.7616337148986 ⎥
# ⎢                                      ⎥
# ⎢-6.13671825336244   -6.81683472832156 ⎥
# ⎢                                      ⎥
# ⎢-32.6878834404533   -32.6944587494642 ⎥
# ⎢                                      ⎥
# ⎢ 4.77343292531001    8.5207253285011  ⎥
# ⎢                                      ⎥
# ⎢-3.81695721761931   -0.39145627123509 ⎥
# ⎢                                      ⎥
# ⎢ -31.795414466755   -31.0643669695332 ⎥
# ⎢                                      ⎥
# ⎢-6.62305350902532   -13.6125641896708 ⎥
# ⎢                                      ⎥
# ⎢ 12.5974808199348    10.9182749385589 ⎥
# ⎢                                      ⎥
# ⎢ 49.0789560219135    54.9761675693709 ⎥
# ⎢                                      ⎥
# ⎢-12.4644932033863   -16.4493096484674 ⎥
# ⎢                                      ⎥
# ⎢ 39.1077988424957    32.9631308978052 ⎥
# ⎢                                      ⎥
# ⎢ 33.1717739885997    32.9370743064283 ⎥
# ⎢                                      ⎥
# ⎢ 50.7738452655529    51.5871972115025 ⎥
# ⎢                                      ⎥
# ⎢ -33.189216865965   -42.2974803468454 ⎥
# ⎢                                      ⎥
# ⎢-54.9983923725314   -62.8144880242884 ⎥
# ⎢                                      ⎥
# ⎢-39.1289020485633   -36.7385312436187 ⎥
# ⎢                                      ⎥
# ⎢-28.4385465644314    -32.381447871458 ⎥
# ⎢                                      ⎥
# ⎢ 20.326016285974     20.5272412290675 ⎥
# ⎢                                      ⎥
# ⎢ 2.38869454135018    5.11519460045229 ⎥
# ⎢                                      ⎥
# ⎢-3.08955145846769   -4.12537879313909 ⎥
# ⎢                                      ⎥
# ⎢ 1.5433834483554    -7.80697854127261 ⎥
# ⎢                                      ⎥
# ⎢ -20.504772615869   -23.6596410450677 ⎥
# ⎢                                      ⎥
# ⎢ 58.6589912769688    67.6176912623032 ⎥
# ⎢                                      ⎥
# ⎢ 35.4249954200622    41.3033287274014 ⎥
# ⎢                                      ⎥
# ⎢ 20.4985877343424    23.6996803150203 ⎥
# ⎢                                      ⎥
# ⎢ 16.392717692231      18.93969720238  ⎥
# ⎢                                      ⎥
# ⎢ 14.9652573032271    14.7913601720539 ⎥
# ⎢                                      ⎥
# ⎢ 0.57254809693817   -1.65084714982961 ⎥
# ⎢                                      ⎥
# ⎢ 21.0619736520882    27.2528608928089 ⎥
# ⎢                                      ⎥
# ⎢-4.70589029165609   -0.612306617140623⎥
# ⎢                                      ⎥
# ⎢ 53.9561125172663    49.6258578668424 ⎥
# ⎢                                      ⎥
# ⎢-27.7387583004946    -26.745261061634 ⎥
# ⎢                                      ⎥
# ⎢-17.1020794340687   -10.6011491971991 ⎥
# ⎢                                      ⎥
# ⎢ 22.7024998789661    34.2594823285142 ⎥
# ⎢                                      ⎥
# ⎢ 16.5151554177775    13.484595385557  ⎥
# ⎢                                      ⎥
# ⎣-5.89530507022243    -2.8195476024408 ⎦

# %%
mean = (np.ones((1, N))/N) @ X_  # dimension: (1 x 200) @ (200 x 2)
mean # dimension: (1 x 2)
# Out:
# array([[1.35294828, 1.59789721]])

# %% [markdown]
# We can verify the result in numpy.

# %%
X_.mean(axis=0)
# Out:
# array([1.35294828, 1.59789721])

# %% [markdown]
# ### Exercise 4
#
# Perform matrix multiplication using **no_mean** and **X\_**, save the result in **X**. Show the mean of **X** with respect to the rows is approximately zero:

# %%
I = np.identity(N)            # 200 x 200 dimensions
col1 = np.ones((1, N))        # 1 x 200 dimensions (col vector)
row1 = np.ones((N, 1)) / N    # 200 x 1 dimensions (row vector)
dotP = row1 @ col1            # (200 x 1) @ (1 x 200) = (200 x 200)
no_mean = (I - dotP)          # (200 x 200) - (200 x 200)
no_mean                       # only plus values in diagonal
# Out:
# array([[ 0.995, -0.005, -0.005, ..., -0.005, -0.005, -0.005],
#        [-0.005,  0.995, -0.005, ..., -0.005, -0.005, -0.005],
#        [-0.005, -0.005,  0.995, ..., -0.005, -0.005, -0.005],
#        ...,
#        [-0.005, -0.005, -0.005, ...,  0.995, -0.005, -0.005],
#        [-0.005, -0.005, -0.005, ..., -0.005,  0.995, -0.005],
#        [-0.005, -0.005, -0.005, ..., -0.005, -0.005,  0.995]])

# %%
X = no_mean @ X_   # (200 x 200) @ (200 x 2) = 200 x 2
X.mean(axis=0)
# Out:
# array([-1.28785871e-15,  2.74447132e-15])

# %%
X.shape, mean.shape
# Out:
# ((200, 2), (1, 2))

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# X=no_mean@X_
# print("mean of X",X.mean(axis=0))
# ```
#
# </details>

# %%
dict_ = {"original data":X_, "zero mean data":X, "mean": mean}
plot_2d(dict_)
# Out:
# [[1.35294828 1.59789721]]

# %% [markdown]
# As we subtracted the mean, we can calculate the `empirical covariance matrix` using matrix multiplication.

# %% [markdown]
# $\displaystyle C=\frac{1}{N}   \mathbf{X}^T \mathbf{X} $
# where,
# X = given dataset
# N = data points (rows)
# D = feature (columns)
# **The mean of each feature is 0. `Principal Component Analysis` (PCA) uses it to find directions of maximum variance.**

# %%
C = X.T @ X / N
Matrix(C)
# Out:
# ⎡844.568024911984  828.254493052263⎤
# ⎢                                  ⎥
# ⎣828.254493052263  844.46941755154 ⎦

# %% [markdown]
# We can see the matrix is full rank:

# %%
matrix_rank(C)
# Out:
# np.int64(2)

# %% [markdown]
# ## Eigen Decomposition

# %% [markdown]
# ### Eigenvectors and Eigenvalues

# %% [markdown]
# If the Matrix is full rank we can apply Eigen factorization or Eigen decomposition to it, so that it is represented in terms of its eigenvalues $\mathbf{\Lambda}$ and eigenvectors embedded in $\mathbf{Q}$, symbolically:

# %% [markdown]
# $\mathbf{A}=\mathbf{Q}\mathbf{\Lambda}\mathbf{Q}^{-1}$

# %% [markdown]
# We can obtain the Matrices as follows:

# %%
Matrix(A)
# Out:
# ⎡-1  1⎤
# ⎢     ⎥
# ⎣1   2⎦

# %%
eigen_values, eigen_vectors = eig(A)

# %% [markdown]
# `eigen_values` is a vector so we convert it to a diagonal matrix  using the `np.diag` function

# %%
Matrix(np.diag(eigen_values))
# Out:
# ⎡-1.30277563773199        0.0       ⎤
# ⎢                                   ⎥
# ⎣       0.0         2.30277563773199⎦

# %% [markdown]
# We can retrieve the original matrix as follows:

# %%
eigen_vectors
# Out:
# array([[-0.95709203, -0.28978415],
#        [ 0.28978415, -0.95709203]])

# %%
inv(eigen_vectors)
# Out:
# array([[-0.95709203,  0.28978415],
#        [-0.28978415, -0.95709203]])

# %%
np.diag(eigen_values)
# Out:
# array([[-1.30277564,  0.        ],
#        [ 0.        ,  2.30277564]])

# %%
A = eigen_vectors @ np.diag(eigen_values) @ inv(eigen_vectors)
Matrix(A)
# Out:
# ⎡-1.0  1.0⎤
# ⎢         ⎥
# ⎣1.0   2.0⎦

# %% [markdown]
# ## Factorization for PCA

# %% [markdown]
# We can only use  eigen decomposition if the matrix is full rank, but even if the matrix is full rank, the eigenvalues and eigenvectors could be complex.
#
# A useful application of the symmetric matrix ($S=S^{T}$) is where we want the eigenvalues to be real and the eigenvectors to be orthogonal. For example, the covariance matrix $C$ in PCA.

# %% [markdown]
# $\mathbf{C}=\mathbf{V}\mathbf{\Lambda}\mathbf{V}^{T}$

# %% [markdown]
# Using numpy,

# %%
eigen_values , eigen_vectors = eig(C)

# %% [markdown]
# We can perform PCA using factorization. To find the first principle component, we need to find the eigenvector with the largest eigenvalue.

# %%
v = eigen_vectors[:, np.argmax(eigen_values)]
v
# Out:
# array([0.70712783, 0.70708573])

# %%
v = v.reshape(-1,1)
v
# Out:
# array([[0.70712783],
#        [0.70708573]])

# %% [markdown]
# We can calculate first principal component by finding the projection of the original data onto $\mathbf{v}$.

# %% [markdown]
# $\mathbf{Z}=\mathbf{X} \mathbf{v}$

# %%
X.shape, v.shape
# Out:
# ((200, 2), (2, 1))

# %%
Z = X @ v # (200 x 2) @ (2 x 1) = (200 x 1)
Z.shape
# Out:
# (200, 1)

# %% [markdown]
# ### Exercise 5
#
# Perform PCA with `n_components=1` on **X**. Store the transformed data in **X_transformed**. Also do an inverse_transform using the same fitted PCA object, store the result in **X\_**.

# %%
# Answer
pca = PCA(n_components=1)
X_transformed = pca.fit_transform(X)
X_transformed.shape
# Out:
# (200, 1)

# %%
X_ = pca.inverse_transform(X_transformed)
X_.shape
# Out:
# (200, 2)

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# pca = PCA(n_components=1)
# X_transformed=pca.fit_transform(X)
# X_=pca.inverse_transform(X_transformed)
#
# ```
#
# </details>

# %% [markdown]
# We can also  transform the data back to its original space, using matrix multiplication:

# %% [markdown]
# $\hat{X}=\mathbf{Z} \mathbf{v}^T$

# %% [markdown]
# ### Exercise 6
#
# Find the transform data back to its original space from the above equation, call it **Xhat**.

# %%
Xhat = Z @ v.T
Xhat.shape
# Out:
# (200, 2)

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# Xhat=Z@v.T
# ```
#
# </details>

# %% [markdown]
# You can also check that the two methods give the same "inverse transform" result (**X\_** and **Xhat** will overlap in the plot) by running the following cell.

# %%
dict_ = {"Sklearn inverse_transform": X_, "Matrix inverse transform": Xhat, "First Principal Component": v.T}
plot_2d(dict_)
# Out:
# [[0.70712783 0.70708573]]

# %% [markdown]
# # Congratulations! - You have completed the lab

# %% [markdown]
# ## Authors

# %% [markdown]
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ENSkillsNetwork20718538-2021-01-01" target="_blank">Joseph Santarcangelo</a> Joseph has a Ph.D. in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# [Roxanne Li](https://www.linkedin.com/in/roxanne-li/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2022-01-01) is a Data Science intern at IBM Skills Network, entering level-5 study in the Mathematics & Statistics undergraduate Coop program at McMaster University.

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By  | Change Description  |
# | ----------------- | ------- | ----------- | ------------------- |
# | 2022-03-25        | 0.1     | Joseph S.   | Updated all content |
# | 2022-05-26        | 0.1     | Roxanne Li  | Review and edit     |
# | 2022-06-09        | 0.1     | Steve H.    | QA pass             |
# | 2022-07-15        | 0.1     | Svitlana K. | Review and edit     |

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
